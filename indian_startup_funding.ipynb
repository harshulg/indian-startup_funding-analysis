# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import numpy as np

# %%
url_1 = 'https://startuptalky.com/indian-startups-funding-investor-data-2024/'
url_2 = 'https://startuptalky.com/indian-startups-funding-investors-data-2025/'

# %%
def scrap_data(url,year):

    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    all_rows = []
    headers = None

    for heading in soup.find_all('h2'):
      table = heading.find_next('table')
      if not table:
          continue

      # Extract month from heading text
      heading_text = heading.get_text(strip=True)

      # Example: "Indian Startup Funding - November 2024 [18 - 23 Nov]"
      # Extract just "November 2024"
      match = re.search(r'([A-Za-z]+) (\d{4})', heading_text)

      if match :
          month = match.group(1)  # First capture group
          year = match.group(2)   # Second capture group

      else :
          month = "Unknown"
          year = "Unknown"


      # Extract headers if not already done
      if not headers:
          headers = [th.text.strip() for th in table.find_all('th')]
          headers.append("Month")  # Add month
          headers.append("Year")   # Add year

      # Extract table rows
      for tr in table.find_all('tr')[1:]:
          cells = [
          td.get_text(strip=True)
          for td in tr.find_all(['td', 'th'])
          if td.get_text(strip=True)  # Only include if not empt
          ]
          if cells:
              cells.append(month)
              cells.append(year)
              if(len(cells)==8):
                all_rows.append(cells)

    df = pd.DataFrame(all_rows, columns=headers if headers else None)

    df.to_csv(f"Startup_Funding_{year}.csv", index=False)

# %%
scrap_data(url_1,2024)
scrap_data(url_2,2025)

# %%
df_2024 = pd.read_csv('Startup_Funding_2024.csv')
df_2025 = pd.read_csv('Startup_Funding_2025.csv')

df_combined = pd.concat([df_2024, df_2025], ignore_index=True)

# %%
df_2025.shape
# Out:
# (471, 8)

# %%
df_combined.shape
# Out:
# (876, 8)

# %%
# def convert_complex_amount_to_inr(amount_str):
#     if pd.isna(amount_str) or not isinstance(amount_str, str):
#         return np.nan

#     amount_str = amount_str.lower().strip()
#     amount_str = amount_str.replace(',', '')

#     # Define multipliers
#     multipliers = {
#         'k': 1e3,
#         'thousand': 1e3,
#         'lakh': 1e5,
#         'lac': 1e5,
#         'm': 1e6,
#         'mn': 1e6,
#         'million': 1e6,
#         'b': 1e9,
#         'billion': 1e9,
#         'cr': 1e7,
#         'crore': 1e7
#     }

#     usd_to_inr = 83  # conversion rate

#     def extract_amount(text, is_usd=False):
#         matches = re.findall(r'([\d\.]+)\s*([a-zA-Z]+)', text)
#         for num, suffix in matches:
#             try:
#                 multiplier = multipliers.get(suffix, 1)
#                 amount = float(num) * multiplier
#                 if is_usd:
#                     amount *= usd_to_inr
#                 return amount
#             except:
#                 continue
#         return None

#     # Try INR first
#     if 'rs' in amount_str or '₹' in amount_str or 'inr' in amount_str or 'Rs' in amount_str:
#         inr_amount = extract_amount(amount_str, is_usd=False)
#         if inr_amount:
#             return round(inr_amount, 2)

#     # Try USD fallback
#     if '$' in amount_str or 'usd' in amount_str:
#         usd_amount = extract_amount(amount_str, is_usd=True)
#         if usd_amount:
#             return round(usd_amount, 2)

#     return np.nan

# %%
def convert_complex_amount_to_inr(amount_str):
    if pd.isna(amount_str) or not isinstance(amount_str, str):
        return np.nan

    amount_str = amount_str.lower().strip().replace(',', '')

    # Multipliers
    multipliers = {
        'k': 1e3, 'thousand': 1e3,
        'lakh': 1e5, 'lac': 1e5,
        'm': 1e6, 'mn': 1e6, 'million': 1e6,
        'b': 1e9, 'billion': 1e9,
        'cr': 1e7, 'crore': 1e7
    }

    usd_to_inr = 83

    # Extract all number + suffix matches
    matches = re.findall(r'([\$₹]?\s*\d+(?:\.\d+)?)\s*([a-zA-Z]+)?', amount_str)

    inr_amounts = []
    usd_amounts = []

    for full, suffix in matches:
        # Clean number and currency
        currency = ''
        num_str = full.strip()

        if num_str.startswith('$'):
            currency = 'usd'
            num_str = num_str[1:]
        elif 'usd' in amount_str:
            currency = 'usd'
        elif any(x in amount_str for x in ['rs', 'inr', '₹']):
            currency = 'inr'

        try:
            num = float(num_str)
            multiplier = multipliers.get(suffix or '', 1)
            amount = num * multiplier

            if currency == 'usd':
                usd_amounts.append(amount * usd_to_inr)
            else:
                inr_amounts.append(amount)
        except:
            continue

    # Prefer INR values if both present, else fallback
    if inr_amounts:
        return round(max(inr_amounts), 2)
    elif usd_amounts:
        return round(max(usd_amounts), 2)
    else:
        return np.nan

# %%
df_combined['Amount_INR'] = df_combined['Amount'].apply(convert_complex_amount_to_inr)

# %%
df_combined
# Out:
#                            Company                         Sector  \
# 0    Zaggle Prepaid Ocean Services             Enterprise Fintech
# 1                     EPACK Prefab       Pre-engineered Buildings
# 2                    Captain Fresh                    Seafood B2B
# 3                          Univest       Retail Advisory Platform
# 4           Mindgrove Technologies           Semiconductor Design
# ..                             ...                            ...
# 871                         Zoplar  Medical Equipment Procurement
# 872                      Moonrider          Electric Tractor Tech
# 873                     Consint.AI                     Healthtech
# 874                       NapTapGo         Affordable Hospitality
# 875                    KIBI Sports                    Sports Tech
#
#       Headquarters                       Amount   Funding Round Type  \
# 0        Hyderabad                 Rs 595 crore        Funding Round
# 1    Greater Noida                  $20 million  First Funding Round
# 2        Bengaluru  Rs 100 crore (~$12 million)        Funding Round
# 3         Gurugram                  $10 million             Series A
# 4          Chennai                   $8 million             Series A
# ..             ...                          ...                  ...
# 871       Gurugram                 $3.4 million             Series A
# 872      Bengaluru   $2.2 million (Rs 19 crore)           Seed Round
# 873          Noida                   Rs 5 crore        Funding Round
# 874          Noida                   Rs 1 crore       Equity Funding
# 875      Bengaluru                     $100,000     Pre-Seed Funding
#
#                                         Lead Investors     Month  Year  \
# 0    Qualified Institutional Placement (Bank of Ind...  December  2024
# 1                                 GEF Capital Partners  December  2024
# 2                         Motilal Oswal Wealth Limited  December  2024
# 3                  Bertelsmann India Investments (BII)  December  2024
# 4    Rocketship.vc, Speciale Invest, Mela Ventures,...  December  2024
# ..                                                 ...       ...   ...
# 871  Blume Ventures, Beenext, Saison Capital, Atriu...   January  2025
# 872  AdvantEdge Founders, Micelio Technology Fund, ...   January  2025
# 873                       Equanimity Ventures, Seafund   January  2025
# 874                             Balmer Lawrie & Co Ltd   January  2025
# 875  Angel Investors including Saurabh Aggarwal, Ar...   January  2025
#
#        Amount_INR
# 0    5.950000e+09
# 1    1.660000e+09
# 2    1.000000e+09
# 3    8.300000e+08
# 4    6.640000e+08
# ..            ...
# 871  2.822000e+08
# 872  1.900000e+08
# 873  5.000000e+07
# 874  1.000000e+07
# 875  8.300000e+06
#
# [876 rows x 9 columns]

# %%
print(df_combined.columns.tolist())
# Out:
# ['Company', 'Sector', 'Headquarters', 'Amount', 'Funding Round Type', 'Lead Investors', 'Month', 'Year', 'Amount_INR']

# %%
df_combined = df_combined.dropna()
df_combined.shape
# Out:
# (816, 9)

# %%
for col in df_combined.columns:
    print(f"Unique values for '{col}': {df_combined[col].nunique()}")
# Out:
# Unique values for 'Company': 769
# Unique values for 'Sector': 638
# Unique values for 'Headquarters': 77
# Unique values for 'Amount': 470
# Unique values for 'Funding Round Type': 132
# Unique values for 'Lead Investors': 727
# Unique values for 'Month': 11
# Unique values for 'Year': 2
# Unique values for 'Amount_INR': 323

# %%
# unqiue values for each couomn

for col in df_combined.columns:
    print(f"Column: '{col}'")
    print(f"  Unique Count: {df_combined[col].nunique()}")
    print(f"  Unique Values: {df_combined[col].unique()}")
    print("-" * 20)
# Out:
# Column: 'Company'
#   Unique Count: 769
#   Unique Values: ['Zaggle Prepaid Ocean Services' 'EPACK Prefab' 'Captain Fresh' 'Univest'
#  'Mindgrove Technologies' 'HostBooks' 'Sparkl Edventure' 'Arata'
#  'Confido Health' 'SustVest' 'Leanworx' 'Proxgy' 'Bureau' 'Bizom' 'Seekho'
#  'ZingBus' 'QuiD Cash' 'Inkers Technology' 'Zunroof' 'Quanfluence' 'Mili'
#  'Curie Money' 'Resilience AI' 'Fitsol' 'Fibroheal Woundcare' 'VOICE'
#  'MBG Card' 'Rebel Foods' 'Mintifi' 'Zetwerk' 'CarDekho SEA' 'Haber'
#  'Wooden Street' 'SolarSquare' 'K12 Techno Services' 'LambdaTest'
#  'OneCard' 'Pixxel' 'Snapmint' 'RapidCanvas' 'Varthana' 'Avanti Finance'
#  'Orange Health Labs' 'Stage' 'DCDC Kidney Care' 'FirstClub' 'FinX'
#  'Culture Circle' 'Superfone' 'Infinity' 'Sustainiam' 'Navanc'
#  'Kreedo Early Childhood Solutions' 'Power Gummies' 'SaveSage Club'
#  'Nodwin Gaming' 'Atmosphere The Store Makers' 'Neuranics'
#  'Annapurna Finance' 'The Money Club' 'Terractive' 'Medial'
#  'Ultraviolette' 'The Indus Valley' 'Enterpret' 'ZFunds' 'WickedGud'
#  'Dentalkart' 'Godrej Properties' 'Agrileaf' 'GoodLives'
#  'AdvantageClub.ai' 'RaptorX' 'MasterChow' 'Vastu Housing' 'Orange Health'
#  'Sportskeeda' 'Hygenco' 'Laurus Bio' 'Candytoy Corporate' 'ALT Mobility'
#  'ShopDeck' 'Elchemy' 'All Things Baby' 'Beyond Appliances' 'Zomato'
#  'Nazara Technologies' 'WadzPay' 'ParkMate' 'Ukhi' 'True Diamond'
#  'NeoGrowth' 'Zepto' 'Healthkart' 'Zopper' 'OneCell Diagnostics'
#  'Vecmocon' 'Kratos Gamer Network' 'Blitz' 'Billion Hearts' 'CredFlow'
#  'Doodhvale Farms' 'Proost' 'Swish' 'Indic Wisdom' 'PeLocal'
#  'Theranautilus' 'Taqtics' 'Matrix Geo Solutions' 'Startup Thamizha'
#  'CADRE ODR' 'UnifyApps' 'Bhanzu' 'Wheelocity' 'The ePlane Company'
#  'Equal' 'Ennoventure' 'Ugaoo' 'Funstop Games' 'Thesys' 'BiteSpeed'
#  'Zeplyn' 'Connecty AI' 'Airbound' 'India IVF' 'DesignX' 'Pikndel'
#  'StampMyVisa' 'LegalKart' 'Creanovation Technologies Pvt. Ltd'
#  'Easy Home Finance' 'Haldiram Bhujiawala' 'EvoluteIQ' 'MODIFI' 'Boldfit'
#  'CynLr' 'GalaxEye' 'Marut Dronetech' 'Hala Mobility' 'The Hosteller'
#  'CastNX' 'Pulse' 'Induz' '30 Sundays' 'Innovartan Learning Solutions'
#  'MOOEV Technologies' 'Heliware' 'Sushain Wellness' 'Viraa Care'
#  'Finova Capital' 'Vridhi Home Finance' 'Udaan' 'Zinc' 'Country Delight'
#  'Arya.ag' 'ARYA' 'Avaana Capital' 'Upgrad' 'Neysa' 'Even Healthcare'
#  'Stellapps' 'Healthify' 'Zouk' 'OLOID' 'Yu' 'GlobalBees Brands'
#  'WishNew Wellness' 'NG Earsafe' 'Purplle' 'Eruditus' 'Neuron7.ai'
#  'Haber Nets' 'Everstage' 'GIVA' 'Primus Senior Living' 'Sistema.bio'
#  'SPRY Therapeutics' 'Anicut Capital' 'Troo Good' 'WROGN' 'Slice'
#  'Simplismart' 'XDLINX Space Labs' 'Dezy' 'Suraasa' 'Budy.bot' 'Wokelo'
#  'AGNIT Semiconductors' 'Yoho' 'Red Fort Capital' 'Perceptyne'
#  'Frammer AI' 'Febi.ai' 'Nayan Tech' 'Data Science Wizards' 'Sorich'
#  'Elixia Robotics' 'Tablesprint' 'Holiday Tribe' 'Lifechart'
#  'iRasus Technologies' 'Flutrr' 'Social Hardware' 'Alchemyst AI'
#  'Beaute Secrets' 'Millenium Babycares' 'Economy Process Solutions'
#  'Urja Mobility' 'Bio Prime' 'Swara Fincare' 'Figr' 'ZenStatement'
#  'Sports For Life' 'Datazip' 'Mstack Chemicals' 'Waycool'
#  'BASIC Home Loan' 'Lissun' 'Zintlr' 'Conscious Chemist'
#  'FermionIC Design' 'IG Drones' 'Clayco Cosmetics' 'Secret Alchemist'
#  'Str8bat' 'OnCare' 'Furnishka' 'ZEVO' 'Ai Health Highway' 'True Balance'
#  'Qure.ai' 'Care.fi' 'Nurix AI' 'Atlys' 'Two Point O Capital'
#  'Ahammune Biosciences' 'Drip Capital' 'InMobi' 'FlexiLoans' 'Centricity'
#  'AppsForBharat' 'Nestasia' 'Clean Electric' 'Dharaksha Ecosolutions'
#  'Mitra' 'Exposome' 'Zivy' 'GameEon' 'Wundrsight' 'Supersquad' 'Omnivore'
#  'Futwork' 'Track3D' 'Crackle Technologies' 'Arnya Real Estate' 'Rapido'
#  'Blue Tokai' 'Nutrabay' 'RecommerceX' 'Invest4Edu' 'Global Care'
#  'BigEndian Semiconductors' 'TruNativ' 'Theater' 'Spolto' 'Valyx'
#  'Boson Whitewater' 'Mytek Innovations' 'LiaPlus AI' 'Sunsure Energy'
#  'Servify' 'Pilgrim' 'Aroa Venture Partners'
#  'Legends League Cricket (LLC)' 'HouseEazy' 'LoanKuber' 'Ben & Gaws'
#  'Miko' 'Cambrian Bioworks' 'ProFinTech Technologies'
#  'Sunfox Technologies' 'Laiqa Wellness' 'The Hive Hostels'
#  'Serigen Mediproducts' 'Acadru' 'ODA Class' 'Medront' 'Yubi' 'Convin'
#  'Plutos ONE' 'Agrim' 'Baazar Style' 'InsurancePadosi'
#  'Finarkein Analytics' 'Kreedo' '99 Pancakes' 'DeepMatrix' 'Hangyo'
#  'Livpure' 'Axio' 'InvestorAi' 'Uppercase' 'Zoff' 'TransBnk' 'LLUMO AI'
#  'Dopplr' 'Revrag' 'Oyo' 'Ather Energy' 'Neo' 'Pakka Limited' 'Syfe'
#  'Vayana' 'Fresh Bus' 'Beco' 'Innoviti' 'Kazam' '4baseCare' 'Skydo'
#  'Fashor' 'Infinyte.Club' 'Truva' 'HealthCRED' 'EyeROV'
#  'Six Sense Mobility' 'Halden' 'MiClient' 'Ziptrrip' 'NuvoRetail'
#  '35North Ventures' 'GenWorks Health' 'Oneiric11 Gaming' 'BiofuelCircle'
#  'Visit Health' 'ShareChat' 'Agrizy' 'Scimplify' 'Kindlife.in'
#  'BlueBinaries Engineering and Solutions' 'Punch' 'Metadome.ai' 'EthrealX'
#  'SigTuple Medtech' 'Aukera' 'Juleo' 'Neuron Energy' 'FINQY' 'Hyperbots'
#  'Burma Burma' 'Karma Primary Healthcare' 'Bebe Burp'
#  'Cellivate Technologies' 'CURRYiT' 'Infibeam Avenues' 'Unicommerce'
#  'WIOM' 'POP' 'Oben Electric' 'Techfino' 'Saswat Finance' 'illumine'
#  'Darwix AI' '7 Ring' 'Nuvie' 'Decentro' 'Sanlayan Technologies'
#  'Roomstory.ai' 'Vecmocon Technologies' 'CRED' 'Flick TV' 'Wow! Momo'
#  'PowerUp Money' 'Garuda Aerospace' 'Piston' 'Leumas' 'Machaxi' 'Knest'
#  'MetaShot' 'Repello AI' 'Kisah' 'Iom Bioworks' 'PlutoPe' 'Spinny'
#  'Qubeats' 'Nxt Meal' 'The Tarzan Way' 'LoanTap' 'Plush' 'Naagin Sauce'
#  'Khari Foods' 'Stride Green' 'Handpickd' 'Gully Labs' 'Manipal Group'
#  'GyanDhan' 'Shapoorji Pallonji' 'Pepperfry' 'Spense' 'Samunnati' 'Snitch'
#  'Stable Money' 'Biopeak' 'Atlanture Sports' 'Mufin Green' 'Slikk'
#  'Citykart' 'EUME' 'Fleetx.io' 'Frinks AI' 'Contineu' 'Orbitt Space'
#  'Myntra' 'GROWiT' 'Saarathi Finance' 'ILIOS 72 Alternative Capital'
#  'Snabbit' 'Cleevo' 'Unbound' 'Battery Smart' 'Euler Motors' 'Cloudsek'
#  'CureBay' 'Miraggio' 'Tan90' 'Misfits' 'Mythik' 'Biostate AI'
#  'Data Sutram' 'Zoca' 'Promethean Energy' 'ALT CARBON' 'OpenFX' 'KSKT'
#  'Farmley' 'Avammune Therapeutics' 'Celebal Tech' 'Citrus Freight'
#  'M1xchange' 'Biryani Blues' 'Be Clinical' 'JSW One' 'TIEA Connectors'
#  'Flam' 'Adopt AI' 'ReelSaga' 'BlueStone' 'VFlowTech' 'ContraVault AI'
#  'Third Bracket' 'LUZO' 'Complement1' 'Hocco' 'NapTapGo' 'MedVital'
#  '1-India Family Mart' 'Zenergize' 'Nobel Hygiene' 'Fyn Mobility' 'Volt14'
#  'Store My Goods' 'Alt DRX' 'Celcius Logistics' '91trucks' 'Troovy'
#  'Nawgati' 'KorinMi' 'The Good Bug' 'InspeCity' 'Insurance Samadhan'
#  'Flipspaces' 'Routematic' 'Shiplog' 'BlissClub' 'Posha' 'PB Healthcare'
#  'Vaya' 'High Time Foods' 'Zebu' 'Feline Spirits' 'GoTrust'
#  'Footprints Preschool & Daycare' 'Porter' 'Uni Seoul' 'Malaki' 'Metafin'
#  'Mugafi' 'CollegeDekho' 'Primebook' 'Scandalous Foods' 'Kult' 'Stimuler'
#  'QNu' 'Vividobots' 'HexaHealth' 'SatLeo Labs' 'Sadhav Offshore'
#  'Anveshan' 'Salt Oral Care' 'Ivana Jewels' 'Fuze' 'Kaleidofin'
#  'Finodaya Capital' 'Ivory' 'MatBook' 'Poshs Metal' 'MyDesignation'
#  'Emversity' 'Vayudh' 'BankBazaar' 'SaveIN' 'Intellicar' 'GreenGrahi'
#  'Rimigo' 'Optimized Electrotech' 'V SAFE' 'Jupiter International'
#  'Cura Care' 'Noto' 'BeastLife' 'CENTA' 'Jewelbox' 'Rio Innobev'
#  'OfBusiness' 'Nothing Before Coffee' 'Peppermint Robotics' 'Magma' 'IPEC'
#  'Easebuzz' 'Asha Ventures' 'Vimano' 'Innovist' 'CalligoTech' 'Juspay'
#  'Sadbhav Future Tech' 'SiglQ.ai' 'OUTZIDR' 'Cautio' 'AgroStar'
#  'Eat Better' 'Amicco' "Let's Try" 'PARÉ Innovations' 'Bhagva' 'Noise'
#  'Xindus' 'Eloelo' 'AskMyGuru' 'Bower' 'Mosaic Wellness'
#  'GreenLine Mobility Solutions Ltd.' 'Koparo' 'Lehlah' 'Tvaster Genkalp'
#  'Evenflow' 'Wendor' 'Stance Health' 'The Bear House' 'DeCharge'
#  'Argos Watches' 'Better Nutrition' 'InnerGize' 'Infinity Fincorp'
#  'Fur Jaden' 'Flipkart Internet' 'Pratilipi' 'RapidClaims' 'FurtherAI'
#  'Sweet Karam Coffee' 'Scapia' 'Perkant Tech' 'DriverShaab'
#  'Tonbo Imaging' 'Aerem Solutions Private Limited' 'Alienkind'
#  'Nexthop AI' 'Abound' 'smallcase' 'Apna Mart' 'Curefoods' 'SHOEGR'
#  'Otipy' 'Slikk Club' 'Protectt.ai' 'Nivara Home Finance' 'Chai Kings'
#  'Qila Games' 'Lighthouse PropTech' 'Iyaso' 'Navadhan' 'Asper.ai'
#  'Everhope Oncology' 'Harvested Robotics' 'Nourish You' 'iHub Robotics'
#  'Hypergro.ai' 'Go Zero' 'Yummy Bee' 'Zolve' 'Purple Style Labs'
#  'AmpereHour Energy' 'goSTOPS' 'indē wild' 'MapMyCrop'
#  'MaxIQ (formerly Gyaan AI)' 'Phot.AI' 'InsuranceDekho' 'Beacon.li'
#  'Darwinbox' 'Nuuk' 'Geniemode' 'Bridgetown Research' 'Oxyzo'
#  'Quick Clean' 'Dr. Reddy’s Laboratories' 'FanTV' 'Vidyut' 'HiWiPay'
#  'Technodysis' 'Sisir Radar' 'Jobizo' 'Astrogate Labs' 'Triple Tap Games'
#  'Dodo Payments' 'Ritualistic' 'Earthful' 'Pickkup' 'Make in Box'
#  'Lightstorm' 'Waterfield Advisors' 'Spyne' 'The Whole Truth' 'Singulr AI'
#  'Dogsee Chew' 'Rare Rabbit' 'Ikonz Studios' 'Probus Smart Things'
#  'Swish Club' 'OneTab AI' 'Almonds Ai' 'NOTO Ice Cream'
#  'Dynolt Technologies' 'You Care Lifestyle' 'Healthfab' 'EnCharge AI'
#  'ToneTag' 'SpotDraft' 'Zeta' '75F' 'JQR' 'Lucidity' 'Nirmata'
#  'BorderPlus' 'Bold Care' 'CapGrid Solutions' 'Nivaan Care' 'Toonsutra'
#  'Mysa' 'Eduvanz' 'ArthAlpha' 'Anscer Robotics' 'The Energy Company'
#  'Future AGI' 'Cogniquest' 'Raincheck Earth Co.' 'Rupeeflo' 'GoRally'
#  'StepOut' 'LegUp' 'Croft Beverages' 'TrueFoundry' 'Cognida.ai'
#  'HairOriginals' 'Nua' 'Scentials' 'Dreamfly Innovations' 'Mealawe'
#  'Fitspire' 'Quicklend' 'Babynama' 'Presage Insights' 'PlaySuper'
#  'Origamis AI' 'Astra Security' 'Meesho' 'Leap' 'Atomicwork' 'SuperOps'
#  'Innov8' 'Geri Care Health Services' 'Emiza' 'VoltUp'
#  'Astrome Technologies' 'Ambak' 'GrowXCD Finance' 'Whizzo' 'Bizloan'
#  'Salad Days' 'CHK' 'Sammmm' 'Origin Fresh' 'Shoppin' 'ThinkMetal' 'Utsav'
#  'MedMitra AI' 'Infra.Market' 'Ati Motors' 'Aris Infra Solutions'
#  'Deconstruct' 'VuNet Systems' 'Medusa Beverages' 'Landeed' 'KisanKonnect'
#  'BPR Hub' 'Pipeshift' 'Zeelab Pharmacy' 'ProcureYard' 'Workie' 'Cancrie'
#  'Raaz App' 'Postudio' 'Chelvies Coffee' 'Krvvy' 'Prantae Solutions'
#  'Exsure' 'Dream Aerospace' 'SVASTEK' 'JoySpoon' 'Aragen' 'Netradyne'
#  'WeWork India' 'Foxtale' 'Ecozen' 'BGauss' 'MicroMitti' 'Sarla Aviation'
#  'Skor Technologies' 'AstroSure.ai' 'Emiza Supply Chain Services'
#  'Eccentric' 'WeVOIS' 'Boba Bhai' 'Constelli' 'Fambo' 'TyrePlex'
#  'Zerocircle' 'KisaanSay' 'ErlySign' 'OrbitAID' 'GreenStitch' 'RePut.ai'
#  'Quash' 'House of Chikankari' 'Tractor Factory' 'Sukoon Unlimited'
#  'Innovaccer Inc.' 'Infinity Fincorp Solutions' 'Botanic Healthcare'
#  'GrayQuest' 'Vehant Technologies' 'Mintoak' 'Beyond Snack' 'Emo Energy'
#  'RAS' 'BrainSight AI' 'hBits' 'Zoplar' 'Moonrider' 'Consint.AI'
#  'KIBI Sports']
# --------------------
# Column: 'Sector'
#   Unique Count: 638
#   Unique Values: ['Enterprise Fintech' 'Pre-engineered Buildings' 'Seafood B2B'
#  'Retail Advisory Platform' 'Semiconductor Design'
#  'Enterprise SaaS Fintech' 'Edtech' 'D2C Haircare' 'AI-focused Healthtech'
#  'Sustainable Investment Platform' 'Manufacturing Data Solutions'
#  'IoT Solutions' 'Risk Intelligence' 'Retail Intelligence'
#  'Learning-focused OTT Platform' 'Intercity Mobility'
#  'Supply Chain Fintech' 'Prop-tech' 'Rooftop Solar'
#  'Photonic Quantum Technology' 'AI Wealth Management Assistant'
#  'Fintech Platform' 'Climate Technology'
#  'Decarbonization for Manufacturing' 'Medical Devices' 'Electric Vehicles'
#  'SaaS' 'Foodtech' 'Supply-Chain Financing' 'Contract Manufacturing'
#  'Digital Automotive Solutions' 'Industrial Robotics'
#  'Furniture & Home Decor' 'Solar Startup' 'Edtech - Schools'
#  'Cloud-Based Testing Platform' 'Credit Card Issuance' 'Spacetech'
#  'Fintech' 'AI Business Transformation' 'NBFC - Education Loans' 'NBFC'
#  'Diagnostics & Healthcare' 'Regional OTT Platform' 'Healthcare'
#  'Quick Commerce' 'Skilling Platform' 'Sneakers & Streetwear'
#  'SMB CRM App' 'Business Banking' 'Climate Tech' 'D2C Gummies'
#  'Credit Card Management' 'Gaming and Entertainment' 'Retail' 'HealthTech'
#  'Financial Services' 'FinTech' 'AgriTech' 'Media and Entertainment'
#  'EV Manufacturing' 'D2C Kitchenware' 'D2C Food Products'
#  'Dental Supplies Marketplace' 'Real Estate' 'Cleantech' 'HRTech'
#  'Housing Finance' 'Supply Chain Financing' 'Diagnostics and Healthcare'
#  'Gaming and Media' 'AI Customer Feedback Platform' 'Biotechnology'
#  'Corporate Services' 'EV Leasing & Management' 'D2C Tech'
#  'Specialty Chemicals' 'Baby & Mothercare' 'Smart Kitchen Appliances'
#  'Food Delivery Platform' 'Gaming' 'Blockchain FinTech'
#  'Road Transport Tech' 'Biomaterials' 'Retail Luxury Goods and Jewellery'
#  'Health Supplements' 'Insurance Infrastructure API' 'Cancer Diagnostics'
#  'EV Components' 'Web3 Gaming' 'Omnichannel Delivery Platform'
#  'Consumer Tech' 'Dairy' 'Beer Startup' '10-minute Food Delivery'
#  'Wood-Pressed Oils' 'Nanorobotics for Healthcare' 'SaaS Platform'
#  'Drone & Space Tech' 'Media' 'Online Dispute Resolution'
#  'Enterprise AI Platform' 'Semi-urban Commerce' 'Electric Aircraft'
#  'Data-sharing & Identity Verification'
#  'Brand Protection & Authentication' 'Houseplants & Urban Gardening'
#  'Casual Gaming' 'AI Software' 'AI-powered Customer OS for E-commerce'
#  'Wealth Management Software' 'Enterprise AI Solutions' 'Drone Technology'
#  'Tech-enabled Fertility Platform' 'Shopfloor Hyper-automation'
#  'Same-day Delivery Service' 'B2B Visa Platform' 'Legal Consultation'
#  'Admissions as a Service' 'Home Financing' 'Snacks' 'Tech Solutions'
#  'B2B BNPL' 'D2C Fitness & Supplements' 'Deep-tech Robotics' 'Drone-tech'
#  'EV-as-a-Service' 'Backpacker Hostel' 'Deep-tech in Power Electronics'
#  'SaaS AI Platform' 'Data Security' 'AI Travel Agent'
#  '3D Geospatial Platform' 'Healthtech' 'MSME-focused NBFC'
#  'Housing finance company' 'B2B platform' 'Edu-wealth' 'D2C'
#  'Grain Commerce' "GPS Renewables'" 'Climate & Sustainability Tech'
#  'AI Cloud' 'Managed Care' 'Dairy Tech Solutions' 'Health & Wellness'
#  'D2C Bags & Luggage' 'Workplace Tech' 'Consumer Food' 'E-commerce'
#  'Wellness' 'Beauty & Personal Care' 'Cloud-based Service Intelligence'
#  'AI-Driven Robotics' 'Sales Performance Management Software' 'Jewelry'
#  'Elder Care' 'Biogas-Tech' 'SaaS - Physical Therapy'
#  'Alternative Asset Management' 'Millet-Based Snacks' 'Men’s Apparel'
#  'Tech' 'Health-Tech' 'Edtech - Teacher Training' 'AI'
#  'Due Diligence Tech' 'Semiconductors' 'Footwear'
#  'Deep Tech AI & Robotics' 'Video Content Creation'
#  'Accounting & Tax Management SaaS' 'AI for Smart City Solutions'
#  'AI Innovation' 'Pharmaceutical Packaging' 'Logistics Automation'
#  'No-Code App Builder' 'Travel-Tech' 'Gut Wellness' 'Energy Analytics'
#  'Vernacular Dating App' 'Assistive Devices' 'Gen-AI SaaS' 'Beauty Tools'
#  'Hygiene care' 'Vacuum systems and process equipment'
#  'EV Battery Leasing' 'Agribiotech' 'Product Design'
#  'Finance Automation and Cash Flow Management' 'Sports Academies'
#  'Data Engineering' 'Chemical manufacturing' 'Agriculture supply chain'
#  'Mortgage distribution' 'Beauty Commerce' 'Semiconductor' 'DroneTech'
#  'FMCG' 'SportsTech' 'Manufacturing' 'EV' 'LendingTech' 'Visa Processing'
#  'Financing Platform' 'Biotech' 'Mobile Advertising - Software'
#  'MSME-Focused Fintech' 'Wealthtech' 'Devotional App - Tech'
#  'Home Decor - D2C' 'Energy Storage' 'FMCG - D2C' 'Clean-tech'
#  'AI - Workplace Solutions' 'Gaming - Game Development'
#  'Digital Therapeutics' 'Creator Monetization' 'Agritech'
#  'Call-center Solutions' 'Ai Construction Industry' 'Adtech'
#  'Bike-Taxi Aggregator' 'Coffee and Bakery' 'D2C Retail'
#  'Chemical Recycling' 'Medical Tourism' 'Nutrition' 'Fashion'
#  'Sports-Tech' 'B2B Financial Management' 'Water Recycling'
#  'Customer Support Solutions' 'Renewable Energy' 'Post-sales Services'
#  'Beauty and Personal Care' 'Investment Fund' 'Sports'
#  'Manufacturing Tech' 'Robotics' 'Health-tech' 'Femtech' 'Hospitality'
#  'Biomedical Products' 'Technology' 'Digital Services for Banking Sector'
#  'B2B Agri-inputs' 'Luxury Fashion' 'Insuretech' 'Data Analytics'
#  'Quick Service Restaurants' 'Deep Tech' 'Food and Beverage' 'Appliances'
#  'Online Lending' 'Equity Investment Platform' 'Luggage' 'Spices'
#  'AI Optimisation' 'Virtual Try-on Solutions' 'B2B Sales'
#  'Wealth and Asset Management' 'Compostable Packaging' 'Trade Finance'
#  'Electric Intercity Bus' 'Eco-Friendly Products' 'Payment Gateway'
#  'E-Mobility' 'Cross-border Payments' 'Ethnic Wear' 'Wealth Management'
#  'Real Estate Tech' 'B2B Healthcare Financing' 'Marine Robotics'
#  'Smart Mobility' 'Luxury Men’s Brand' 'AI-driven B2B Sales Platform'
#  'Travel-tech SaaS' 'E-commerce Marketing' 'Venture capital'
#  'eCommerce Marketing & Analytics' 'Esports and Gaming Platform'
#  'Marketplace for biomass and biofuel' 'Social Media Company'
#  'Dairy and Essentials' 'Speciality Chemicals'
#  'Beauty, wellness, and health' 'Engineering, Tech Services'
#  'Stock Broking' 'XR Startup' 'Medtech' 'Lab-grown Jewellery' 'Dating App'
#  'EV Batteries' 'AI for Finance, Accounting' 'Vegan Restaurant'
#  'Baby Food' 'Food and Beverages' 'Gaming, Media'
#  'Consumer Services/ Enterprise Services' 'Enterprise Tech'
#  'Artificial Intelligence' 'Ecommerce' 'Defence Electronics' 'Deep-tech'
#  'OTT platform' 'Electric mobility' 'QSR' 'Drone startup'
#  'Digital payment' 'Deeptech' 'Sportstech' 'Construction-tech'
#  'AI security' 'D2C Jewellery' 'Men’s ethnicwear' 'Deep science'
#  'Decentralized finance (DeFi)' 'Used car platform' 'Quantum Computing'
#  'Food Tech' 'Online Travel' 'Alternative Lending'
#  'Personal Care Products' 'Food & Beverage' 'Online Grocery'
#  'Green SME Loans' 'Fashion Tech' 'Education, Healthcare'
#  'Higher Education Tech' 'B2B E-Commerce' 'Home Improvements'
#  'Investment Tech' 'Agri-financing' 'D2C Menswear Brand'
#  'API Banking / Fintech' 'Wellness & Longevity' 'Sports & Media'
#  'Lab-Grown Diamond Jewellery' 'EV Financier' 'Fashion Delivery'
#  'Value fashion retailer' 'Premium Travel Luggage Brand'
#  'Manufacturing AI' 'Fashion ecommerce' 'Quick service app' 'Home hygiene'
#  'Enterprise AI security and governance' 'Battery swapping'
#  'Cybersecurity' 'Community Platform' 'Media Technology' 'Agentic AI'
#  'FX infrastructure' 'Agri-commerce' 'Snacking' 'IT services provider'
#  'Shipping' 'Skincare' 'B2B e-commerce'
#  'B2B ESDM (Electronic System Design and Manufacturing)'
#  'Mixed Reality Content' 'Mobile-first entertainment'
#  'Omnichannel jewellery' 'Vanadium redox flow battery'
#  'Tender and RFP management' 'Hiring Platform'
#  'Marketplace for salons, spas, and wellness clinics' 'Ice Cream Brand'
#  'Pod Hotel' 'MedTech' 'Value retail chain' 'Disposable hygiene' 'EVaaS'
#  'Battery Tech' 'Storage Solutions' 'Digital Real Estate'
#  'Cold chain aggregator' 'Commercial vehicle marketplace'
#  'Kids-focused nutrition food brand' 'Fuel aggregator'
#  'Korean skin clinic' 'Gut health-focused' 'Insurance'
#  'Interior design and contracting' 'Transport-as-a-service'
#  'Logistics-Tech' 'Women-focused direct-to-consumer' 'Kitchen Robotics'
#  'Food-tech' 'Defense Tech' 'Craft alcoholic beverage'
#  'Privacy compliance' 'Early childhood education and daycare' 'Logistics'
#  'Lifestyle' 'Beverage' 'Healthcare Fintech' 'Android Laptop'
#  'B2B Indian sweets' 'Beauty Tech' 'Cyber Security' 'Space Tech'
#  'Maritime Service' 'D2C Food' 'Pre-Series A' 'Lab-grown Diamonds'
#  'Digital Assets Infrastructure' 'Non-banking financial company'
#  'Construction Tech' 'Cloud Kitchen' 'Steel Processing' 'D2C Fashion'
#  'Drone Startup' 'Loan Sourcing' 'Fabric' 'Agri-biotech' 'Travel Tech'
#  'IoT' 'Solar solutions' 'Oral Care' 'Nutrition Brand' 'Education'
#  'D2C lab-grown diamond jewellery' 'Beverage Startup' 'B2B commerce'
#  'QSR coffee chain' 'Aerospace' 'B2B manufacturing' 'EV charging'
#  'B2B Fintech' 'Venture Capitalist' 'Nanotech' 'Beauty Products'
#  'Agri-Renewable' 'D2C Apparel' 'Visual Telematics' 'D2C Snacking'
#  'B2B marketplace' 'D2C Snack Brand' 'building material segment'
#  'Digital Spirituality' 'Wearables' 'Cross-border Logistics'
#  'Live Social Entertainment' 'Spiritual-tech' 'Health and wellness'
#  'Green Logistics' 'Influencer Commerce' 'Used-car sales' 'Multi-brand'
#  'Smart Vending' 'D2C Menswear' 'EV Charging Solutions'
#  'Luxury watch brand' 'Biofortified food brand' 'D2C mental health tech'
#  'Luggage and lifestyle brand' 'Marketplace' 'Storytelling App'
#  'AI Revenue Cycle Management' 'AI Assistants' 'Foods and Beverages'
#  'Travel fintech' 'B2B mobility solutions provider' 'Defence tech'
#  'Solartech' 'Juice Brand' 'Finance' 'Online investment platform'
#  'Dairy products brand' 'FMCG Chain' 'Health Service' 'Shoe care'
#  'Mobile App Security' 'Housing loan' 'D2C Beauty Brand' 'Chai Retail'
#  'PropTech' 'Speech Therapy' 'AI-powered supply chain'
#  'Plant-based Nutrition' 'Humanoid robotics' 'Ice Cream' 'Café chain'
#  'Cross-border NeoBank' 'Chemicals Startup' 'Omnichannel Luxury Fashion'
#  'Ayurvedic Skincare' 'Food Delivery' 'Insurtech' 'HR technology'
#  'D2C home appliances' 'B2B Cross-Border E-commerce'
#  'SaaS - Research Analytics' 'Fintech - NBFC Lending'
#  'Linen Management - SaaS' 'Pharmaceutical Company'
#  'Content - Blockchain/Sui Network' 'EV Full-Stack Platform'
#  'Fintech - Cross-border Payments' 'IT - Cloud & DevOps Solutions'
#  'Spacetech - SAR Satellite Imaging'
#  'HRTech - Healthcare Staffing Solutions'
#  'Spacetech - Satellite Communications'
#  'Fintech - Payments Infrastructure' 'Home Decor - D2C Brand'
#  'Plant-Based Nutrition - D2C Wellness'
#  'Logistics - Hyperlocal Deliveries' 'Deeptech - Engineering Solutions'
#  'Cloud & Data Centre Networking' 'B2B E-commerce'
#  'Wealth Advisory - Fintech' 'AI-Powered Visual Merchandising - AutoTech'
#  'Clean Label Health Food - D2C' 'D2C Pet Treats'
#  'Omnichannel Fashion Retailer' 'Digital Avatars & Holography - AI/VR'
#  'IoT & Data Analytics' 'Devices-as-a-Service - DaaS'
#  'Workplace SaaS - AI Solutions' 'Loyalty & Rewards Platform - SaaS'
#  'D2C - Health Foods' 'Deeptech - AI & Analytics'
#  'Independent Verification - E-commerce' 'D2C - Reusable Period Panties'
#  'AI Chips - Semiconductor' 'Digital Payments - Fintech'
#  'Contract Lifecycle Management - CLM SaaS' 'Banking Tech - Fintech SaaS'
#  'Commercial HVAC Automation - IoT & AI' 'Mobility - Bike Taxi Services'
#  'Affordable Footwear - D2C' 'Multi-Cloud Storage - SaaS'
#  'D2C Protein Bars - Foodtech' 'SaaS - Cloud Security'
#  'Global Workforce Mobility' 'D2C Sexual Wellness - Healthtech'
#  'B2B Manufacturing - Supply Chain SaaS'
#  'Chronic Pain Management - Healthtech' 'Webtoon & Comics - MediaTech'
#  'Unified Finance - Fintech SaaS' 'Education Loan - Fintech'
#  'Investment Tech - Wealthtech' 'Deeptech - Robotics'
#  'EV Battery Solutions' 'AI Infrastructure'
#  'Intelligent Document Processing - SaaS AI' 'Alcoholic Beverage - D2C'
#  'Fintech - Lending Platform' 'Pickleball Chain - Sports'
#  'Sports Tech - Performance Analysis'
#  'Caregiving Tech - Family & Wellness' 'Sustainable Tea - AgriTech D2C'
#  'E-commerce - Fashion' 'Seafood Supply Chain' 'AI Deployment & Scaling'
#  'D2C Hair Extensions & Wigs' 'Women’s Wellness & Hygiene' 'D2C Wellness'
#  'Health & Nutrition' 'Secured Lending' 'Digital Pediatric Care'
#  'IoT & AI Predictive Maintenance' 'Gaming Commerce' 'GenAI Startup'
#  'Edtech - Student Mobility' 'B2B SaaS' 'IT Management SaaS' 'Coworking'
#  'Senior Healthcare' 'EV Infrastructure' 'Telecom - E-band Solutions'
#  'NBFC - MSME Lending' 'Materials Science Manufacturing'
#  'NBFC - SME Lending' 'D2C Footwear' 'Gaming - Console'
#  'Teen Self-care Brand' 'Fresh Produce D2C' 'Fashion Search Engine'
#  'Deeptech - Manufacturing' 'Spiritual & Devotion Platform'
#  'Healthtech - AI-driven Solutions' 'Construction Materials'
#  'Gaming & Media' 'Tech-enabled Procurement' 'D2C Skincare'
#  'Business Observability' 'Beer Manufacturing' 'Quick Service App'
#  'Property Title Search Engine' 'D2C Food Brand'
#  'Compliance for Manufacturers' 'B2B Raw Materials'
#  'Office Space Management' 'Nanocarbon Materials' 'Post-Production SaaS'
#  'Coffee & Dining Brand' 'D2C Lingerie & Shapewear' 'Aerospace & Defense'
#  'Mouth Freshener' 'Contract R&D and Manufacturing'
#  'AI & Edge Computing SaaS' 'Flexible Workspace'
#  'Climate-Focused Deeptech' 'Electric Two-Wheeler Manufacturing'
#  'Proptech' 'Aerospace & Electric Flying Taxis'
#  'Credit & Financial Services' 'Astro-Tech' 'Logistics & Warehousing'
#  'Automotive 3D Tech' 'Waste Management' 'QSR - Bubble Tea'
#  'B2B Tyre Marketplace' 'Biotech - Seaweed Alternatives' 'Food Brand'
#  'Climate Tech - Fashion' 'Parking Management' 'Supply Chain Solutions'
#  'AI Startup' 'D2C Ethnic Wear' 'Agetech' 'Healthcare AI' 'Nutraceutical'
#  'B2B Food & Agritech' 'Edtech/Fintech' 'Security & Surveillance'
#  'Banana Chips Brand' 'Energy Tech' 'Luxury Skincare'
#  'Deep-tech Neuroscience' 'Commercial Real Estate'
#  'Medical Equipment Procurement' 'Electric Tractor Tech'
#  'Affordable Hospitality' 'Sports Tech']
# --------------------
# Column: 'Headquarters'
#   Unique Count: 77
#   Unique Values: ['Hyderabad' 'Greater Noida' 'Bengaluru' 'Gurugram' 'Chennai' 'Delhi'
#  'New Delhi' 'New Jersey, US' 'India' 'Ichalkaranji' 'Mumbai' 'Jabalpur'
#  'Singapore' 'Pune' 'Jaipur' 'San Francisco' 'Austin' 'Auckland' 'Indore'
#  'Bhubaneswar' 'Noida' 'Belthangady Taluk, Daskshina Kannada District'
#  'Ahmedabad' 'Uttar Pradesh' 'Tortola' 'Sonepat' 'New York (Mumbai)'
#  'San Francisco, United States' 'Kolkata'
#  'Bengaluru (Regstd Indian Office)' 'Telangana' 'Dewas, Madhya Pradesh'
#  'Gurgaon' 'Lucknow' 'Chandigarh' 'Rajkot' 'United States'
#  'Houston, TX, United States' 'Palo Alto, US' '-' 'Raipur' 'Haryana'
#  'Dehradun' 'Mangalore' 'London' 'Kanpur' 'Kochi' 'California, US'
#  'Troy, Michigan' 'Dover' 'Udaipur' 'Surat' 'GiFT, Gandhinagar'
#  'Karnataka' 'Maharashtra' 'Tamil Nadu' 'US' 'Nashik' 'Bhubaneshwar'
#  'Posha' 'Abu Dhabi' 'Thiruvananthapuram' 'Thanjavur' 'Akola'
#  'Vishakhapatnam' 'Patna' 'Delhi and Mumbai' 'Ernakulam' 'San Fracisco'
#  'California' 'Bahadurgarh' 'Washington' 'Coimbatore' 'Faridabad' 'Nagpur'
#  'Hoshiarpur' 'Alappuzha']
# --------------------
# Column: 'Amount'
#   Unique Count: 470
#   Unique Values: ['Rs 595 crore' '$20 million' 'Rs 100 crore (~$12 million)' '$10 million'
#  '$8 million' '$5 million' '$4 million' '$4 million (~Rs 34 crore)'
#  '$3 million' '$1.7 million' 'Rs 8.3 crore (~$1 million)'
#  '$3 million (ongoing)' '$30 million' '$12 million'
#  'Rs 59 crore (~$7 million)' '$4.5 million (~Rs 38.23 crore)'
#  'Rs 20 crore (~$2.3 million)' '$2 million' '$1.2 million' '$1 million'
#  'Rs 6.3 crore (~$760,000)' 'Rs 5 crore (~$600,000)'
#  'Rs 2.72 crore (~$327,000)' '$210 million' '$180 million' '$70 million'
#  '$60 million' '$44 million' 'Rs 354 crore (~$43 million)' '$40 million'
#  '$38 million' '$25.5 million' '$24 million' '$18 million' '$16 million'
#  '$15 million (~Rs 120 crore)' '$14.2 million (~Rs 120 crore)'
#  'Rs 84.6 crore (~$10 million)' 'Rs 82 crore (~$10 million)' '$6 million'
#  '$1.9 million (~Rs 15.8 crore)' '$1.9 million (~Rs 16 crore)'
#  '$1.45 million (~Rs 12.14 crore)' 'Rs 10 crore (~$1.2 million)'
#  'Rs 2.5 crore (~$300,000)' 'Rs 64 crore' 'Rs 5 crore' '$700K'
#  '$109.5 million' '$2.5 million' 'Rs 8 crore' '$500K' 'Rs 130 crore'
#  'Rs 23.1 crore' '$20.8 million' 'Rs 25 crore' 'Rs 20 crore' 'Rs 85 crore'
#  'Rs 6,000 crore' 'Rs 1.1 crore' 'Rs 4 crore' '$6.5 million'
#  '$100 million' '$80 million' '$8.14 million' 'Rs 50 crore' 'Rs 120 crore'
#  '$28.5 million' 'Rs 110 crore' '$5.6 million' 'Rs 30 crore'
#  'Rs 8,500 crore' 'Rs 855 crore' 'SGD $50 million' '$350 million'
#  '$153 million' '$25 million' 'Rs 51 crore' '$3.7 million' '~$1 million'
#  'Rs 3.3 crore' '$200,000' '$16.5 million (Rs 139 crore)' '$15 million'
#  '$14 million' '$8.9 million' 'Rs 47 crore ($5.6 million)' '$3.5 million'
#  '$1.8 million' '$1.24 million' 'Rs 6.6 crore' 'Rs 6.5 crore'
#  '$35 million' 'Rs 235 crore' 'Rs 110 crore ($13 million)' '$6.2 million'
#  'Rs 51 crore ($6 million)' 'Rs 48 crore' 'Rs 23.22 crore' '$1.4 million'
#  '$780,000' '$770,000' 'Rs 2 crore' '$108,000' '$135 million' 'Rs 310 Cr'
#  'Rs 300 Cr' 'Rs 200 Cr' '$19.8 million' 'Rs 100 Cr' '$26 million'
#  'Rs 55 crore' 'Rs 4.5 crore' '$250,000' 'Rs 1.06 crore'
#  'Rs 1,500 crore ($180M)' '$150 million' 'Rs 255 crore' '$11 million'
#  '$9 million' 'Rs 75 crore ($9 million)' 'Rs 71.7 crore ($8.6 million)'
#  '$7 million' '$4.2 million' 'Rs 27 crore' 'Rs 22.6 crore' 'Rs 5.4 crore'
#  '$500,000' 'Rs 3.75 crore' 'Rs 3.2 crore' '$300,000' 'Rs 1.6 crore'
#  'Rs 100 crore ($12 million)' 'Rs 19.4 crore ($2.3 million)'
#  '$2.25 million' '$1.62 million' '$1.1 million'
#  'Rs 100 crore ($12 million approx.)' '$10.6 million' '$8.6 million'
#  '$3.2 million' '$2.4 million' '$65 million' 'Rs 8 Cr' '$27.5 million'
#  '$6.3M' '$5M' '$113 million' 'Rs 290 crore ($35M)' '$8.35 million'
#  'Rs 24.8 crore ($2.95M)' 'Rs 11 crore' 'Rs 10 crore' '$400K'
#  'Rs 2.1 crore' 'Rs 20.9 crore ($2.5 million)' '$4.3 million'
#  'Rs 375 crore' '$200 million' 'Rs 48.5 crore' 'Rs 32 crore'
#  '$3.6 million' '$1.5 million' '$800K' 'Rs 6 crore' 'Rs 226 crore'
#  '$340 million' 'Rs 84 crore' 'Rs 75 crore' 'Rs 40 crore' 'Rs 39 crore'
#  'Rs 33.5 crore' 'Rs 20.5 crore' '$1.45 million' 'Rs 15 crore'
#  'Rs 11.5 crore' '$0.5 million' '$17.3 million (Rs 145 crore)'
#  'Rs 250 crore' '$500,000 (or approximately Rs 4.19 crore)'
#  '$4.75 million' '$4 million (Rs 33 crore)' 'Rs 20 crore ($2.4 million)'
#  '$1.6 million' '$25 million (Rs 211 crore)' 'INR 208 crore ($25 million)'
#  'INR 169 crore ($20 million)' 'INR 167 crore ($20 million)'
#  'INR 80 crore ($10 million)' 'INR 75 crore ($9 million)'
#  'INR 40 crore ($4.8 million)' '$1 million (INR 8 crore)' '$750,000'
#  '$600K' 'Rs 1,457 crore ($175 million)' 'Rs 600 crore ($71 million)'
#  'Rs 400 crore ($48 million)' 'Rs 244.7 crore'
#  '$27 million (Rs 226 crore)' '$20.5 million'
#  'Rs 87.5 crore ($10.5 million)' 'Rs 70 crore ($8.5 million)'
#  'Rs 10 Crore ($1.2 million)' 'Rs 3.9 crore' '$350k' 'Rs 100 crore'
#  'Rs 41 crore' 'Rs 45 crore ($5.3 million)'
#  'Rs 250 crore ($29.7 million approx.)' 'Rs 70 crore ($8.45 million)'
#  '$9.8 million' '$9.5M' 'Rs 60 crore ($7.2 million)'
#  'Rs 33 crore ($4 million)' 'Rs 26.7 crore ($3.2 million)'
#  'Rs 11 crore ($1.3 million)' 'Rs 8 crore ($1 million)' '$27 Mn'
#  '54% Stake' 'Rs 124.5 crore' '$35 Mn' '$30 Mn' '$11.5 Mn' '$7.5 Mn'
#  '$2.6 Mn' '$2.5 Mn' '$1.5 Mn' '$462K' '$450K' 'Rs 30 Crore'
#  'Rs 186 crore' 'Rs 3 crore' '$18 Mn' 'Rs 617 crore' '$2.3 Mn' '$6 Mn'
#  'Rs 85 Cr' '$7.1M' 'Rs 375 Cr' '$6.1M' '$2.2 Mn' 'Rs 300 crore'
#  'Rs 450 Cr' 'Rs 13 crore' 'Rs 4 Cr' 'Rs 5 Cr' '$2.91M' '$750K' '$233K'
#  '$6.29M' '$2.33M' '$4.66M' '$2.1M' '$350K' '$3.5M' '$2.53M' '$129K'
#  '$600M' '$5.85M' '$75M' '$114M' '$5.06M' '$1.85M' '$5.84M'
#  '₹50 Cr (~$6M)' '$40M' '$20M' '₹30 Cr (~$3.6M)' '$3M' '₹21 Cr (~$2.5M)'
#  '₹26 Cr (~$3.1M)' 'Rs 538 crore' 'Rs 113 Crore' '$5.4 million'
#  '$124 million' 'Rs 475 Crore' 'Rs 1 crore' '$19 million' 'Rs 280 crore'
#  '$29 million' 'Rs 638 crore' '$21 Mn' 'Rs 20 Cr' 'Rs 5 Crore' '$9 Mn'
#  '$2 Mn' '$12 Mn' '$23Mn' '$1.3 Mn' 'Rs 2.5 Cr' '$10Mn' '$6.5Mn' '$5 Mn'
#  'Rs 2 Cr' 'Rs 340 Cr' 'Rs 22 Cr' '$14Mn' '$2.1 Mn' 'Rs 40 Cr' '$20.5 Mn'
#  'Rs 5.1 Cr' '$550K' '$10 Mn' 'Rs 8.4 crore' '$20 Mn' '$2.5Mn' '$1.87 Mn'
#  'Rs 23 Cr' '$360K' 'Rs 250 Cr' 'Rs 43 Cr' 'Rs 3 Cr' '$5.6Mn' 'Rs 8.5 Cr'
#  '$35Mn' '$40 Mn' 'Rs 6.5 Cr' 'Rs 33 Cr' '$8Mn' '$218 Mn' '$1.2 Mn'
#  '$1 Mn' 'Rs 5.2 Cr' '$7.5Mn' '$200 Mn' 'Rs 5.7 Cr' 'Rs 6 Cr' '$3 Mn'
#  '$3.75 Mn' 'Rs 60 Cr' 'Rs 1.47 Cr' '$12 Million' '$3.3 Mn' 'Rs 25 Cr'
#  'Rs 48 Cr' '$12.2 Mn' '$5.3 Mn' 'Rs 43 crore' '$1.25 million'
#  'Rs 37 crore' '$13.5 million' '$300K' 'Rs 500 Cr' 'Rs 21 Cr'
#  'Rs 1.9 crore' '$3.2Mn' 'Rs 10 Cr' '$4 Mn' '$5Mn' 'Rs 136 Cr' '$1.1 Mn'
#  '$60 Mn' 'Rs 36 Cr' '$9.5 Mn' 'Rs 30 Cr' 'Rs 11 Cr' '$6.7 Mn' 'Rs 17 Cr'
#  '$8.5Mn' '$13.5 Mn' 'Rs 11.5 Crore' '$20Mn' 'INR 12.5 crore'
#  '$131 million' 'INR 50 crore' 'INR 6.5 crore' 'INR 10 crore'
#  'INR 4.5 crore' 'INR 3,249 crore'
#  '$11 million ($8 million and $3 million)' 'INR 6.6 crore' 'INR 2.8 crore'
#  'INR 175 crore' 'INR 100 crore' '$110 million' '$50 million'
#  'INR 214 crore' 'INR 150 crore' '$6.6 million' '$100K'
#  'Rs 76 Cr ($8.7 million)' 'Rs 245 Cr' '$500k' 'Rs 111 crore'
#  'Rs 16 crore' 'Rs 4.3 crore' 'Rs 7 crore' 'Rs 18 crore' '$251 million'
#  '$14 Mn' 'Rs 15.7 Cr' '$7.8 million' '$2.7Mn' '$70Mn' '$7 Mn' '$140 Mn'
#  'Rs 100 crore ($12M)' 'Rs 50 crore ($5.7M)' '$1.3 million'
#  'Rs 5 crore ($600K)' '$260K' 'Rs 700 crore ($80.5M)' '$75 million'
#  'Rs 50 crore ($6M)' '$4.5 million' '$3.3 million (Rs 28.6Cr)'
#  'Rs 16 crore ($1.9M)' 'Rs 15 crore ($1.75M)' '$100 million+'
#  '$78 million' '$54 million' '$45 million' 'Rs 250 crore ($29.7M)'
#  '$21 million' 'Rs 133 crore ($16M)' '$9.6 million'
#  '$5 million (Rs 43 Cr)' '$4.25 million' '$2.8 million' 'Rs 25.52 crore'
#  '$2 million+' 'Rs 6.6 crore ($750K)' 'Rs 2 crore ($250K)' '$125K'
#  '$81 million' 'Rs 250 crore ($30 million)' 'Rs 43.5 crore ($5 million)'
#  'Rs 35 crore' 'Rs 34.6 crore ($4 million)' 'Rs 12 crore'
#  'Rs 6.75 crore ($774K)' '$700,000' 'Rs 5.6 crore' '$2.7 million'
#  '$500-$550 million' 'Rs 35 crore ($4.16M)' 'Rs 30 crore ($3.6 million)'
#  'Rs 10 crore ($1.2 million)' '$800,000' 'Rs 6.35 crore' '$121 million'
#  'Rs 495 crore ($60 million)' 'Rs 80 crore' 'Rs 65 crore ($7.7 million)'
#  'Rs 60 crore ($6.94 million)' 'Rs 56 crore' '$5.5 million' '$2.6 million'
#  '$1.72 million' 'Rs 6.1 crore ($705K)' 'Rs 56 lakh' '$90 million'
#  'Rs 500 crore ($57.8 million)' '$23 million' 'Rs 161 crore ($20 million)'
#  'Rs 90 crore' 'Rs 50 crore ($6 million)' 'Rs 36 crore ($4.2 million)'
#  'Rs 21 crore ($2.5 million)' 'Rs 16 crore ($1.8 million)' '$635,000'
#  '$430,000' '$275 million' 'Rs 550 crore ($65 million)'
#  'Rs 80 crore ($9.3 million)' 'Rs 71 crore' '$8.3 million' '$3.4 million'
#  '$2.2 million (Rs 19 crore)' '$100,000']
# --------------------
# Column: 'Funding Round Type'
#   Unique Count: 132
#   Unique Values: ['Funding Round' 'First Funding Round' 'Series A' 'Seed Round'
#  'Pre-Series A (Equity & Debt)' 'Series B' 'Pre-Series A' 'Series G'
#  'Series E' 'Fresh Funding' 'External Funding Round' 'Series C'
#  'Investment' 'Series B (Additional Funding)' 'Debt and Equity Round'
#  'Strategic Investment' 'Equity Funding' 'Maiden Funding Round'
#  'Debt Funding' 'Bridge Round' 'Angel Funding'
#  'Convertible Preferred Stock' 'Seed' 'Multilateral ECB Transaction' '-'
#  'QIP' 'Growth' 'Pre-Seed' 'Debt' 'Equity Investment' 'Series D'
#  'Qualified Institutions Placement (QIP)' 'Preferential Issue'
#  'Share Subscription Facility' 'Conventional Debt' 'Pre-Series B'
#  'Seed Funding' 'Pre-IPO Round' 'Extended Series A' 'Pre-seed Round'
#  'Fresh Funding Round' 'Minority Stake' 'Equity and Debt Funding Round'
#  'New Funding Round' 'Funding Participation' 'Equity and Debt'
#  'Pre-seed Funding' 'Debt Financing' 'Seed funding' 'Financing Round'
#  'Mezzanine financing' 'New Fund' 'Additional Investment' 'Series A1'
#  'Angel Round' 'Series F' 'Extended Series B' 'Private Credit Fund 3'
#  'Series A Round' 'Additional Funding' 'Pre-Series A Round'
#  'Pre-IPO Funding' 'Investment in Startup' 'Pre-Seed Round'
#  'Cash Flow Financing' 'Private Placement Round' 'Investment Round'
#  'Venture Round' 'Equity Round' 'Equity & Debt' 'Debt Fund'
#  'Follow-on Financing Round' 'Capital Commitment' 'Pre-IPO Funding Round'
#  'Equity capital' 'Venture Funding' 'Right Issue' 'Non-convertible debt'
#  'Series A3' 'Fundraise' 'Debt Round' 'Series C Extension' 'Acquisition'
#  'Pre-seed' 'Down Round' 'Seed round' 'Funding round' 'Covertible Debt'
#  'Grant (Prize Money)' 'Venture Debt' 'Pre-seed funding'
#  'Institutional Round' 'Equity and Debt Round' 'secondary deal'
#  'Pre-series C' '$2.1 Mn' 'Growth Funding Round' 'Strategic Funding Round'
#  'Equity funding round' 'Angel Fund' 'pre-Series A' 'Angel Funding Round'
#  'Series E Round' 'Series A, Seed Round' 'Series D pre-IPO funding round'
#  'Equity and Funding Round' 'Mix of Primary and Secondary Funding'
#  'Pre-Seed Funding' 'Funding' 'Undisclosed Round'
#  'Series A + Debt Funding' 'Pre-Series Funding'
#  'Secondary + Primary Funding' 'Growth Funding'
#  'Investment Round (Valued at $2B)' 'VC Funding (First Institutional)'
#  'Institutional Investment Round' 'Bridge Funding Round'
#  'Capital Infusion' 'Pre-Series C' 'Debt & Equity'
#  'Bridge Round (Pre-Series A)' 'Primary and Secondary Equity'
#  'Primary Funding Round' 'Seed & Pre-Series A' 'Series X' 'Rights Issue'
#  'Series F (Primary & Secondary)' 'Equity Financing' 'Series B (Equity)'
#  'Mezzanine Round' 'Secondary Funding']
# --------------------
# Column: 'Lead Investors'
#   Unique Count: 727
#   Unique Values: ['Qualified Institutional Placement (Bank of India - largest buyer)'
#  'GEF Capital Partners' 'Motilal Oswal Wealth Limited'
#  'Bertelsmann India Investments (BII)'
#  'Rocketship.vc, Speciale Invest, Mela Ventures, Peak XV Partners, Nishchay Goel, Whiteboard Capital, Anshul Goel'
#  'Orange Orbit (as part of a $15M Series B funding round)'
#  'Rainmatter Foundation (Nithin Kamath), Zomato’s Deepinder Goyal'
#  'Unilever Ventures, L’Oréal’s BOLD Ventures, Skywalker Family Office'
#  'Together Fund, MedMountain Ventures, Rebellion VC, DeVC, Operators Studio, strategic healthcare operators'
#  'Inflection Point Ventures, Antler, WEH Ventures, Venture Catalysts, Soonicorn Ventures, FAAD Network'
#  'YourNest Venture Capital, angel investment group'
#  'Ajinkya Rahane, Nikhil Kamath, Suniel Shetty, Vinod Duggar, Manish Patel'
#  'Sorenson Capital, PayPal Ventures, Commerce Ventures, GMO Venture Partners, Village Global, Quona Capital, XYZ Ventures'
#  'Pavestone ($7.5M), IndiaMART, and family offices' 'Lightspeed'
#  'BP Technology Ventures'
#  'Angel investors, including Piyush Jain, and MINTCAP'
#  'Ashish Kasholia (Lucky Investments)'
#  'ANBG Enterprise LLP (Godrej Family Office), Ravindernath Chadha'
#  'pi Ventures, Golden Sparrow, Reena Dayal'
#  'Chiratae, BoldCap, Sparrow Capital, SFMG Wealth Advisors, Gregg Fisher (Quent Capital), Better Capital'
#  'India Quotient, institutional and angel investors'
#  'Kalaari Capital (CXXO Initiative)' 'Transition VC'
#  'Existing promoters, surgeons, medical professionals, and bankers'
#  'BizDateUp' 'Inflection Point Ventures, Velocity, Klub'
#  'Temasek, Evolvence'
#  'Teachers’ Venture Growth (TVG), Prosus, Premji Invest'
#  'Khosla Ventures, Baillie Gifford, Rakesh Gangwal'
#  'Navis Capital Partners, Dragon Fund' 'Creaegis, BEENEXT, Accel'
#  'Premji Invest'
#  'Lightspeed, Lightrock, Elevation Capital, Chris Sacca’s Lowercarbon, Nithin Kamath’s Rainmatter, Gruhas Proptech'
#  'Kenro Capital' 'Avataar Ventures, Qualcomm Ventures'
#  'QED Investors, Peak XV Partners, Z47, Better Tomorrow Ventures'
#  'M&G Catalyst, Glade Brook Capital Partners, Google, Radical Ventures, Lightspeed'
#  'Prashasta Seth (Prudent Investment Manager), Perpetuity Ventures, Pegasus Fininvest'
#  'Peak XV Partners, Titanium Ventures, Accel, Valley Capital Partners'
#  'BlueOrchard Microfinance Fund'
#  'Dia Vikas Capital, IDH Farmfit Fund, NRJN Family Trust, Rabo Partnerships'
#  'Amazon Smbhav Venture Fund, Accel, General Catalyst, Bertelsmann India Investments, Y Combinator'
#  'Goodwater Capital, Blume Ventures'
#  'British International Investment (BII)'
#  'Accel, RTP Global, Blume Founders Fund, Quiet Capital, 2am VC, angel investors'
#  'Elevar Equity' 'Info Edge Ventures, angel investors'
#  'YourNest Venture Capital, Ankur Capital, Finsight Seed Fund, angel investors'
#  'Y Combinator, Liquid 2 Ventures, Script Capital, angel investors'
#  'Orios Venture Partners, Shilpa Shetty Kundra, Rajesh Sawhney, Harsh Vardhan Bhagchandka, Vinit Bhansali'
#  'Prarambh Ventures, Inflection Point Ventures (IPV), Brigade REAP, angel investors'
#  'Recur Club'
#  'Jaipuria Family Office, Quadrant, 100unicorn, DSGCP, Wipro Consumer, Venture Catalysts, others'
#  'iSEED, Alluvium Fund, LetsVenture Fund, angel investors'
#  'Nazara Technologies'
#  'Artha Venture Fund and PIL Italica Lifestyle Limited'
#  'Inflection Point Ventures (IPV)' '-' 'Prudent Investment Managers'
#  'Fireside Ventures and DeVC (anchored by Z47)'
#  'Ortella Global Capital (OG Capital)'
#  'Zoho Corporation, Lingotto Co-Invest Fund I, Mudhal Partners, others'
#  'DSG Consumer Partners'
#  'Kleiner Perkins, Peak XV Partners, Wing Ventures, Recall Capital'
#  'Elevation Capital' 'Orios Venture Partners'
#  'Malabar Investment, Whiteoak'
#  'Singapore sovereign wealth firm GIC, SBI Pension'
#  'Capital-A and Samarsh Capital'
#  'IIM Lucknow, Rabindranath Tagore University (RNTU), Build3'
#  'Axilor Ventures' 'PeakXV Spark, EagleWings Ventures, Point One Capital'
#  'Tanglin Venture Partners' 'Prosus' 'Amazon Smbhav Venture Fund'
#  'Trifecta' 'Canaan Partners' 'Eight Roads Ventures and F-Prime Capital'
#  'Better Tomorrow Ventures, Peak XV, Z47'
#  'Domestic investors, HNIs, angel investors, institutional investors'
#  'Eurazeo, Shell Ventures, Twynam Earth Fund, EV2 Ventures'
#  'Bessemer Venture Partners, Elevation Capital, Venture Highway, and Chiratae Ventures'
#  'Prime Venture Partners, InfoEdge Ventures'
#  'Manish Choksi Family Office, Richa Choksi'
#  'Fireside Venture Investment Fund III, Dharana Capital, Shezan Bhojani, Saurabh Jain, Ramakant Sharma, Chandru Kalro'
#  'SBI Mutual Fund, Caratlane founder Mithun Sacheti, Aamara Capital, Think Investments  among others'
#  'GEM Global Yield LLC SCS' 'Cactus Partners (CPL)'
#  '100Unicorns, Venture Catalysts, Avtar Monga'
#  'Titan Capital, Huddle Ventures, Zeropearl Ventures, Ashutosh Valani, Priyank Shah, Aashka Goradia Goble, Ghazal Alagh, Abhishek Goyal, Anmol Jain'
#  'Symbiotics Group'
#  'Motilal Oswal Private Wealth, Raamdeo Agarwal, Taparia Family Office, Mankind Pharma Family Office, Celebrity Investors, others'
#  'ChrysCapital, Motilal Oswal Alternates'
#  'Elevation Capital, Dharana Capital, Blume Ventures'
#  'Celesta Capital, Tenacity Ventures, Cedars Sinai, Eragon, Singularity Ventures'
#  'Ecosystem Integrity Fund (EIF), Blume Ventures, British International Investment (BII)'
#  'Aptos Labs, Polygon, Game7' 'IvyCap Ventures' 'Blume Ventures'
#  'Inflexor Ventures, Singapore-based family office'
#  'Atomic Capital, Singularity Early Opportunities Fund, Bharat Founders Fund, others'
#  'Chimes Group, Srinivasan Namala, Hyderabad Angels, The Chennai Angels, others'
#  'Accel' 'Rockstud Capital, others' 'Unicorn India Ventures' 'Pi Ventures'
#  'Sprout Venture Partners, Capital-A, Java Capital'
#  'Chittorgarh Infotech Limited, Viney Equity Markets LLP, Tryrock Capital Trust AIF'
#  'Mudhal Partners'
#  'Aprameya Radhakrishna, Murali Subramanian, Ram Bhamidi, Aneesh Garg, Rahul Guptan'
#  'ICONIQ Growth, Elevation Capital' 'Epiq Capital'
#  'Lightspeed, Alteria Capital, Anicut Capital, Company’s Founder'
#  'Speciale Invest, Antares Ventures, Micelio Mobility, Naval Ravikant, Java Capital, others'
#  'Prosus Ventures, Tomales Bay Capital, Keshav Reddy'
#  'Tanglin Venture Partners, Fenice Investment Group, SAFE Investors'
#  'V3 Ventures, DSG Consumer Partners, RPG Ventures'
#  '360 ONE Asset, InfoEdge Ventures' 'Together Fund, 8vc'
#  'Peak XV Surge, Whiteboard Capital, Gaurav Munjal, Aakash Anand, Dhruv Vohra, others'
#  'Leo Capital, Converge, Angels and VC Funds'
#  'Market One Capital, Notion Capital, Marcin Zukowski, Maciej Zawadzinski'
#  'Lightspeed, gradCapital, Angel Investors' 'Tomorrow Capital'
#  'Piper Serica Angel Fund'
#  'VC Grid, D2C Insider Angels, Breathe Capital, Venture Catalysts, industry leaders, family offices'
#  'IIM Udaipur Incubation Centre, Aevitas Capital, Shift Alt Cap, others'
#  'Physis Capital'
#  'Ranjan Pai’s family office, Claypond Capital, Sumitomo Mitsui Banking Corporation’s Asia Rising Fund'
#  'Bharat Value Fund (BVF), managed by Pantomath Capital Management'
#  'Round2 Capital, Nordea Growth Fund, Dcap Select, PH Ventures'
#  'SMBC Asia Rising Fund, Maersk, Intesa Sanpaolo, Heliad'
#  'Bessemer Venture Partners'
#  'Pavestone, Athera Venture Partners, Speciale Invest, Infoedge (Redstart), and other investors'
#  'Mounttech Growth Fund' 'Lok Capital'
#  'Srikanth Reddy, Snehith Reddy, Phani Ramineni, Rohan Bajaj syndicate, Sarthy Angels, Bestvantage, HNIs'
#  'V3 Ventures, Blacksoil (Debt)'
#  'Arpit Khandelwal, Plutus Investments and Holding Private Limited'
#  'Endiya Partners, Zluri founders, Yellow.ai founders, other angel investors'
#  'YourNest Venture Capital, SanchiConnect'
#  'Infoedge Ventures, First Cheque, Eximius, Misfits, other angel investors'
#  'Gokul Rajaram, Amit Singhal'
#  'Bizdateup, Inflection Point Ventures, Spectrum Impact (Aarti Industries Family Office)'
#  'JITO Incubation and Innovation Foundation (JIIF), TiE, Vatvistaar Ventures'
#  'Prajay Advisors LLP' 'European angel investors'
#  'Avataar Venture Partners\ufeff, Sofina\ufeff, Madison India Capital\ufeff, and Norwest Venture Partners'
#  'Norwest Venture Partners'
#  'Lighthouse Canton, Stride Ventures and others'
#  'Nexus Venture Partners, Quona Capital, EDBI, Global Ventures, and Saison Capital'
#  'Alteria Capital' 'US International Development Finance Corporation'
#  'Incred, Spark Capital'
#  'Fundraising for climate and sustainability tech startups' 'Temasek'
#  'NTTVC, Z47 (formerly Matrix Partners India), Nexus Venture Partners'
#  'Khosla Ventures, Founders Fund, 8VC, Lachy Groom'
#  'Blume Ventures, Omnivore, Bill & Melinda Gates Foundation, IDH Farmfit Fund, 500 Global, Blue Ashva Capital, Miledeep Capital'
#  'Khosla Ventures, LeapFrog Investments'
#  'Aavishkaar Group, Stellaris Venture Partners, Titan Capital, Sharrp Ventures, JJ Family'
#  'Yaletown Partners, Exposition Ventures, George Kaiser Family Foundation, Carya Ventures'
#  'Ashish Kacholia, Asian Promoter Group'
#  'Dynamic IT Solution Private Limited (Subsidiary of Brainbees Solutions)'
#  'Ankit Khnadelwal, Gyanesh Sharma (DotPe), Abhijeet Rana, Ashish Singh'
#  'Inflection Point Ventures'
#  'Abu Dhabi Investment Authority (ADIA), Premji Invest, Blume Ventures'
#  'TPG’s The Rise Fund' 'Smith Point Capital'
#  'Creaegis, Accel, BEENEXT Capital'
#  'Eight Roads Ventures, Elevation Capital, 3one4 Capital'
#  'Premji Invest, Epiq Capital, Edelweiss Discover Fund'
#  'General Catalyst, Nikhil Kamath (Zerodha), Gruhas'
#  'ElectriFI, Chroma Impact Investment, KawiSafi Ventures, AXA IM Alts'
#  'Flourish Ventures, Together Fund, Fidelity’s Eight Roads, F-prime Capital'
#  'GIFT City Structure'
#  'Puro Wellness, Oaks Asset Management, V Ocean Investments'
#  'Aditya Birla Digital Fashion Ventures Ltd (ABDFVL)'
#  'Rajan Bajaj (Founder & CEO)'
#  'Accel, Shastra VC, Titan Capital, Akshay Kothari (Notion Co-founder)'
#  'Ashish Kacholia (Lucky Investments), E2MC, Mana Ventures'
#  'Alphawave, Chiratae Ventures, Peak XV’s Surge'
#  'Reach Capital, ETS Capital, NB Ventures, TSM Ventures, TRTL Ventures'
#  'RTP Global' 'Not disclosed' '3one4 Capital, Zephyr Peacock'
#  'Gulf Islamic Investments (GII)' 'Debt Round'
#  'Endiya Partners, Yali Capital, Whiteboard Capital' 'Lumikai'
#  'Lumis Partners, Virender Rana, Amit Chaudhary (Lenskart), Rohan Bhargava (Cashkaro)'
#  'BEENEXT, We Founder Circle, Venture Catalysts, Lets Venture, FAAD Capital'
#  'JITO Incubation and Innovation Foundation (JIIF)'
#  'Angel Investors (Ankit Bhati, Ajeet Khurana, etc.)'
#  'Powerhouse Ventures, GSF, Dinesh Agarwal (IndiaMart), Murugavel Janakiraman (BharatMatrimony)'
#  'Prajay Advisors LLP, Angel Investors'
#  'Rohit Rajput, Srikar Reddy (IAN Angel), DFAN, Other Angel Investors'
#  'Zee Media'
#  'Inflection Point Ventures, Ivyleague Ventures, Soonicorn Ventures'
#  'Inflection Point Ventures, 100Unicorns, Early Seed Ventures'
#  'Velocity (Cash Flow Financing Platform)' 'Bharat Value Fund'
#  'Stakeboat Capital Fund II' 'Hindon Mercantil and Mufin Green Finance'
#  'Edaphon, Omnivore, Inflexor' 'Serica Angel Fund and UC Impower'
#  'Antler, Golden Sparrow, individual investors, and Kalaari Capital'
#  '3One4 Capital, Boldcap VC, Atrium Angels'
#  'Roots Ventures, ML Tondon and Sons HUF and Blume Ventures'
#  'Equirus InnovateX Fund' 'Lightspeed and Alphawave' 'Grand Anicut'
#  'Bertelsmann India Investments, CE-Ventures, Gruhas, 9 Unicorns, and others'
#  'RPSG Capital Ventures' 'Om Jain' 'Atomic Capital' 'Ashish Kacholia'
#  'India Accelerator' 'Oaks Asset Management' 'Unilever Ventures'
#  'Samantha Prabhu' 'Exfinity Venture Partners' 'Huddle Ventures'
#  'IndiaQuotient' 'Turbostart' 'VentureSoul Partners'
#  'Lightspeed and 360One Asset' 'Wint Wealth and Caspian'
#  'General Catalyst\ufeff, Accel, and Meraki Labs'
#  'Peak XV Partners and Elevation Capital' 'Omnivore' 'pi Ventures'
#  'GMO Payment Gateway, SMBC'
#  'MARS Growth Capital (MUFG and Liquidity Group)'
#  'Accion, Nuveen, Fundamentum, Maj Invest'
#  'Lightspeed, Paramark VC, Burman Family Office, MS Dhoni Family Office'
# ...
#  'Accel India' 'Prath Ventures and Spring Marketing Capital' 'Eximius'
#  'SWC Global' 'Advenza Global Limited' 'Pradeep Nain' 'Bose Corporation'
#  '3one4 Capital and Orios Venture Partners' 'Play Ventures'
#  'High-Net-Worth Individuals (HNIs) and Astir Ventures' 'Think Investment'
#  'Nikhil Kamath' 'Saama Capital' 'Accel Leaders Fund' 'Ideaspring Capital'
#  'Venture Catalysts, Sunder Ramachandran' 'Elanpro' 'General Catalyst'
#  'Lemniscap' 'Group of high-net-worth Indian investors'
#  'Family offices and high-net-worth individuals (HNIs)'
#  'Beams Fintech Fund' 'Gruhas Collective Consumer Fund'
#  'Flipkart Marketplace Private Limited in Singapore' 'Jungle Ventures'
#  'Accel, Together Fund' 'Peak XV Partners' 'YourNest Venture Capital'
#  'Florintree Advisors, Tenacity Ventures and the Export-Import Bank of India'
#  'UTEC' 'Prakash Sikaria, Ravi Iyer, Arpan Sheth'
#  'Lightspeed Venture Partners' 'NEAR Foundation' 'Elev8'
#  'Temasek, V-Sciences Investments' 'Accel and Fundamentum' 'ABC Impact'
#  'BlackSoil, Binny Bansal and Caspian Investments' 'Nuvama' 'True North'
#  'NSFO' 'A.V. Thomas and Co' 'Chimera VC' 'Malpani Ventures' 'NabVentures'
#  'Fractal' 'Arali Ventures' 'U.S. investors'
#  'DSG Consumer Partners, Saama Capital and V3 Ventures'
#  'Mile Deep Capital'
#  'Creaegis, HSBC, SBI Investment, GMO Venture Partners'
#  'Accel, Bertelsmann India, UMI, Omnivore and 3one4 Capital'
#  'SageOne Flagship Growth OE Fund, Alchemy Long Term Ventures Fund, Bajaj Holdings and Investment, and Minerva Ventures Fund'
#  'Unilever Ventures, SoGal Ventures, The Global Ventures'
#  'Hara Global Capital, Accel India'
#  'YourNest Venture Capital, Eaglewings Venture'
#  'Dell Technologies Capital, Intel Capital'
#  'Info Edge Ventures, Together Fund, AC Ventures'
#  'Beams Fintech Fund, Japan’s Mitsubishi UFJ Financial Group (MUFG), and insurer BNP Paribas Cardif'
#  'Sorin Investments' 'Partners Group and KKR'
#  'Vertex Ventures SEAI, Good Capital'
#  'Multiples Alternate Asset Management, Fundamentum, Paramark Ventures, Info Edge Ventures'
#  'Lightspeed, Accel' 'AK Capital Finance'
#  'Alkemi Growth Capital, Blue Ashva Capital, Rs 10 crore ($1.15M) credit line from Venture Debt Cos'
#  'Acquired a 0.32% stake by Go Digit (Insurtech - Investments)'
#  'Mysten Labs, Cypher Capital, CoinSwitch Ventures, Illuminati Capital'
#  'Flourish Ventures'
#  "Unicorn India Ventures, Dewang Neralla's Family Office, Jupiter Metaverse LLP, Ritesh Malik, Mitesh Shah, Nilesh Doshi"
#  'Shastra VC, Riverwalk Holdings, INVSTT' 'Alkemi Growth Capital'
#  'Eximius Ventures, Kalaari Capital, Angel Investors from Entertainment & Gaming Community'
#  'Antler, 9Unicorns, Venture Catalysts, Nitin Gupta, Maninder Gulati, Raymond Russell, Preethi Kasireddy, Nishant Verman'
#  'Deep Bajaj, Mohit Bajaj' 'Srinivasan Namala'
#  'We Founder Circle (WFC), Angel Investors'
#  'Mile Deep Works, Mile Deep Capital'
#  'NIIF Infrastructure Finance Limited (NIIF IFL)'
#  'Series G Equity Funding'
#  'Jungle Ventures (Primary & Secondary Investment)'
#  'Vertex Ventures, Accel, Storm Ventures, Alteria Capital'
#  'Sofina, Z47, Peak XV Partners, Sauce.VC'
#  'Nexus Venture Partners, Dell Technologies Capital'
#  'Ektha.com, Shivanssh Holdings, Poddar Family Office' 'A91 Partners'
#  'Marc Jordan, Ramana Thummu, Madhusudan Kela, Akash Bhanshali'
#  'Unicorn India Ventures, US-based & Indian Family Offices'
#  'Powerhouse Ventures, Blume Ventures, Founders Fund, Touchstone Ventures, Eternal Capital, Atrium Ventures'
#  'LIT Fund, Orbit, Singapore Family Office, SOSV, Sunil Kumar Singhvi, Founders'
#  'Promoters of Haldiram’s, JITO Incubation & Innovation Foundation (JIIF), Venture Catalysts, Ever Grow Capital, Nine ALPS'
#  'Inflection Point Ventures (IPV), JITO Incubation & Innovation Foundation, LetsVenture'
#  'Transition VC, Yashowardhan Shah' 'Luke Coutinho, Narendra Firodia'
#  'Mistry Ventures, BeyondSeed, Thrive Ventures, Anupam Mittal, Aman Gupta, Vineeta Singh, Peyush Bansal'
#  'Tiger Global' 'ValueQuest Scale Fund, Iron Pillar'
#  'Vertex Growth Singapore, Trident Partners, Xeed VC, Arkam Ventures, Prosus Ventures, Premji Invest'
#  'Strategic Investor'
#  "Accurant International's Net Zero Alliance, Carrier Global Corporation, Climate Investment, Breakthrough Energy Ventures, Next47, WIND Ventures"
#  'Venturi Partners' 'WestBridge Capital, Alpha Wave'
#  'Sofina Ventures, Peak XV Partners, Matrix Partners, Sauce.vc'
#  'Peak XV’s Surge, Dallas Venture Capital, Dreamit, Z5 Capital, Uncorrelated Ventures'
#  'Owl Ventures'
#  'Zerodha’s Rainmatter, Mithun Sacheti (CaratLane), Siddhartha Sacheti (Jaipur Diamond), Gruhas Collective Consumer Fund, Claris Capital'
#  'Anicut Growth Fund, Nexus Venture Partners, Axilor Ventures'
#  'Endiya Partners, W Health Ventures'
#  'Holtzbrinck Publishing Group, GMJP, T-Accelerate, Google, Graphic India'
#  'Blume Ventures, EMVC, Antler, Neon Fund, CIIIE, Sriharsha Majety (Swiggy), Mohit Kumar (Ultrahuman), Naiyaa Saagi (MyGlamm), Nitin Gupta (Uni)'
#  'Juvo Ventures, Capria Fund, Peak XV, Unitus Ventures'
#  'DSP, Family Offices, Wealth Managers' 'Info Edge Ventures'
#  'Siana Capital, Callapina Capital, Z21 Ventures, 1Crowd, LetsVenture, other investors'
#  'Powerhouse Ventures, Snow Leopard Ventures, AngelList Quant Fund, Saka Ventures, Swadharma Source Ventures, 30+ industry stalwarts'
#  'Cedar IBSI Capital, Dexter Venture, AngelList, Congniphy US'
#  'Japanese Investors, AngelList India Syndicate'
#  'Sujeet Kumar, Mohit Kumar, Vatsal Singhal, Viren Singhvi, Kartik Kapoor, Abhishek Goyal, Deepak Singh, Arjun Vaidya, Bharat Founders Fund'
#  'Rainmatter (Nithin Kamath), IndigoEdge, Marwah Sports Group, Misfits Capital'
#  'Bluebridge Capital Private Limited'
#  'Angel Investors from tea, sustainability, IT, biotech sectors'
#  'Flipkart (Parent Company)'
#  'Prosus Ventures, Accel, Tiger Global, family office of Sriharsha Majety (Swiggy), Sid Khanna, Sunjay Kapur, Shivalik Prints'
#  'Intel Capital, Eniac Ventures, Peak XV’s Surge, Jump Capital, Gokul Rajaram, Mohit Aron, Cyan Banister, Fortune 1000 executives'
#  'Anicut Growth Fund, 12 Flags Consumer Holdings, Peyush Bansal (Lenskart)'
#  'Mirabilis Investment Trust, Samir Singh (Colgate Palmolive), Shuchi Kothari (DSP Family Office)'
#  'Indus Way Emerging Market Fund, TIW Private Equity'
#  'Avaana Capital, Sunicon Ventures'
#  'Shark Tank founders, FDI, angel investors from Goldman Sachs, Oracle'
#  "McDonald's India (North & East) Promoter Anant Agarwal, MM Agrawal Group (MMG), AKG financials"
#  'Inuka Capital, Eximius Ventures, Upsparks Capital, GrowX, strategic angel investors'
#  'Good Capital, Amplify, Abhishek Gupta (Fashinza), Ankit Gupta (Bicycle Health), Akshay Saxena (Avanti), Dhruv Dhanraj Bahl (Ex-BharatPe)'
#  'YourNest Venture Capital (YourNest-SanchiConnect Velocity Program 2024)'
#  'IAN Angel Fund, 100X.VC, angel investors (Uday Sodhi, KRS Jamwal, Pratham Mittal, Rajit Bhattacharya, Ankit Das)'
#  'Vikas Gautam, Naveen Agarwal'
#  'Emergent Ventures, The Neon Fund, Better Capital, Blume Ventures, PointOne Capital'
#  'Tiger Global, Think Investments, Mars Growth Global, Peak XV Partners, WestBridge Capital'
#  'Apis Growth Markets Fund III, Apis Global Growth Fund III, Owl Ventures, Jungle Ventures, Peak XV Partners'
#  'Khosla Ventures, Z47 (formerly Matrix Partners India), Battery Ventures, Blume Ventures, Peak XV Partners'
#  'March Capital, Lee Fixel’s Addition, Z47'
#  'Mankind Pharma, Gauri Khan, Rupa Group, Jagruti Dalmia'
#  'InvAscent (India Life Sciences Fund IV)'
#  'Evolvence India, Mirabilis Investment Trust'
#  'EM Impact Capital (UK-based impact investment firm)'
#  'Apollo Fund, IAN Group'
#  'Peak XV’s Surge, Advantedge VC, DeVC, angel investors'
#  'Lok Capital, UC Impower' 'Lightspeed, BEENEXT'
#  'Michael & Susan Dell Foundation, BLinC Invest'
#  'V3 Ventures, Client Associates Alternate Fund (CAAF)'
#  'Accel, Bluestone, individual investors'
#  'Sauce.vc, Sharrp Ventures, Panthera Peak Capital'
#  'Fireside Ventures, Sauce VC, Nihir Parikh, Sachin Parikh, Shantanu & Nikhil Mehra'
#  'Aeravti Ventures, Ultra HNIs'
#  'YourNest Venture Capital, Concept Communications, Sanchi Connect'
#  'Equanimity Investments' 'All In Capital, WEH Ventures'
#  'Axana Estates LLP, Arpit Khandelwal, Mithun Sacheti'
#  'Walden Catalyst Ventures, NGP Capital, True Ventures, Exfinity Venture Partners, Athera Venture Partners, Blume Ventures'
#  'Mukul Agrawal (Param Capital)'
#  'BOLD (L’Oréal’s VC Fund), V3 Ventures, DSG Consumer Partners, Kalaari Capital, Beenext'
#  'Pravega Ventures, Kotak Securities, Mela Ventures, Athera Venture Partners, Dallas Venture Capital, TVS Capital Funds'
#  'Amal N Parikh, Ashwin Kedia, Ramesh Damani, Nikhil Garg, Crest Opportunities, HNIs (Singapore, UK, UAE)'
#  'Elevation Capital, Nexus Venture Partners, Vidit Aatrey, Sanjeev Barnwal, Gaurav Munjal, Niraj Singh'
#  '10x Founders Fund, Oliver Jung, Paradigm Shift, Pioneer Fund, others'
#  'Mistry Ventures, Brand Capital, Shilpa Shetty, VC-Grid, Vishwang Desai'
#  'Y Combinator, SenseAI Ventures, Arka Venture Labs, Good News Ventures, others'
#  'OTP Ventures'
#  'Powerhouse Ventures, Java Capital, 2am VC, angels including Abhishek Goyal and Rajesh Sawhney'
#  'Sunil Singhania Family Office, NAV Capital, Raman Roy, others'
#  'Roots Ventures, IIMA Ventures'
#  'Fireside Ventures, Campus Fund, Better Capital'
#  'Audacity Venture Capital' 'Endurance Capital'
#  'Titan Capital, All In Capital, angels such as Nikita Gupta, Emmanuel Suraj, and others'
#  'IAN Group, IAN Alpha Fund, Samir Kalia, Deepank Kumar, Nitin Zamre'
#  'IAN Angel Fund' 'Dishit Nathwani, Prateek Toshniwal, others'
#  'Quadria Capital'
#  'Point72 Private Investments, Qualcomm Ventures, Pavilion Capital'
#  'Rights Issue'
#  'Kose Corporation, Z47 (Matrix Partners India), Kae Capital, Panthera Growth Partners'
#  'responsAbility Investments AG, Northern Arc Capital Limited, Maanaveeya Development & Finance Private Limited'
#  'Bharat Value Fund (BVF)'
#  'Prominent HNIs, family offices, and business leaders'
#  'Argor Capital, QED Investors, Saison Capital, Digital Currency Group'
#  'Pradeep Dadha, others' 'Evolvence India, Mirabilis Investment'
#  'Exfinity Venture Partners, Arkam Ventures'
#  'Negen Capital, Vyom Wealth, Venture Catalysts, SN Capital, Warmup Ventures, Marsshot Ventures, others'
#  'Pravega Ventures' 'EV2 Ventures, Rajesh Sawhney, UHNIs'
#  'PeerCapital, Titan Capital Winners Fund, Sattva Family Office, others'
#  'Rainmatter, 1Crowd, VC Grid, 7th Gen Ventures, Trudie Styler'
#  'Jungle Ventures (First Cheque@Jungle), senior food industry leaders'
#  'Unicorn India Ventures, TANSIM (Tamil Nadu Government)'
#  'Equirus InnovateX Fund, Ivycap Ventures, Warmup Ventures, Zeca Ventures'
#  'Cactus Partners, Venture Catalysts, Marwah Group Family Office'
#  'GrowthCap Ventures, angel investors'
#  'Arali Ventures, Java Capital, PeerCheque, DeVC (Matrix Partners), Tracxn Co-founder'
#  'Tudip Ventures, Peyush Bansal (Lenskart), Ankit Nagori, others'
#  'All In Capital, Bharat Founders Fund, Devc, family offices'
#  'Anchorage Capital Partners, Vinay Jain, Manish Dureja, others'
#  'B Capital Group, Banner Health, Danaher Ventures LLC, Generation Investment Management, Kaiser Permanente, M12'
#  'Redsprig Innovation Partners (Ritesh Agarwal’s affiliated entity)'
#  'Jungle Ventures, Archerman Capital, Magnifico'
#  'Stakeboat Capital, Abakkus Four2Eight Opportunities Fund, DS Group'
#  'IIFL Fintech Fund, Claypond Capital (Ranjan Pai Family Office), Pravega Ventures'
#  'True North’s Private Credit Fund' 'Z3Partners' '12 Flags Group'
#  'Subhkam Ventures, Microtek Group, SRK Family Office, Transition VC'
#  'Ambis Holding US, Kuberan Ventures, Karimjee Group, Mission Vertical, Sanjeev Saraf Family Office, Pravek Kalp Family Office, others'
#  'Unilever Ventures, Amazon Smbhav Venture Fund'
#  'IAN Alpha Fund, IvyCap Ventures, Silver Needle'
#  'Capricon Realty Private Limited (Thackersey Group)'
#  'Blume Ventures, Beenext, Saison Capital, Atrium Angels, Finfirst, LogX'
#  'AdvantEdge Founders, Micelio Technology Fund, angel investors'
#  'Equanimity Ventures, Seafund' 'Balmer Lawrie & Co Ltd'
#  'Angel Investors including Saurabh Aggarwal, Arpit Bhardwaj, Vartika Joshi, others']
# --------------------
# Column: 'Month'
#   Unique Count: 11
#   Unique Values: ['December' 'November' 'October' 'September' 'August' 'June' 'May' 'April'
#  'March' 'February' 'January']
# --------------------
# Column: 'Year'
#   Unique Count: 2
#   Unique Values: [2024 2025]
# --------------------
# Column: 'Amount_INR'
#   Unique Count: 323
#   Unique Values: [5.9500e+09 1.6600e+09 1.0000e+09 8.3000e+08 6.6400e+08 4.1500e+08
#  3.3200e+08 3.4000e+08 2.4900e+08 1.4110e+08 8.3000e+07 2.4900e+09
#  9.9600e+08 5.9000e+08 3.8230e+08 2.0000e+08 1.6600e+08 9.9600e+07
#  6.3000e+07 5.0000e+07 2.7200e+07 1.7430e+10 1.4940e+10 5.8100e+09
#  4.9800e+09 3.6520e+09 3.5400e+09 3.3200e+09 3.1540e+09 2.1165e+09
#  1.9920e+09 1.4940e+09 1.3280e+09 1.2000e+09 8.4600e+08 8.2000e+08
#  4.9800e+08 1.5800e+08 1.6000e+08 1.2140e+08 1.0000e+08 2.5000e+07
#  6.4000e+08 5.8100e+07 9.0885e+09 2.0750e+08 8.0000e+07 4.1500e+07
#  1.3000e+09 2.3100e+08 1.7264e+09 2.5000e+08 8.5000e+08 6.0000e+10
#  1.1000e+07 4.0000e+07 5.3950e+08 8.3000e+09 6.6400e+09 6.7562e+08
#  5.0000e+08 2.3655e+09 1.1000e+09 4.6480e+08 3.0000e+08 8.5000e+10
#  8.5500e+09 4.1500e+09 2.9050e+10 1.2699e+10 2.0750e+09 5.1000e+08
#  3.0710e+08 3.3000e+07 1.6600e+07 1.3900e+09 1.2450e+09 1.1620e+09
#  7.3870e+08 4.7000e+08 2.9050e+08 1.4940e+08 1.0292e+08 6.6000e+07
#  6.5000e+07 2.9050e+09 2.3500e+09 5.1460e+08 4.8000e+08 2.3220e+08
#  1.1620e+08 6.4740e+07 6.3910e+07 2.0000e+07 8.9640e+06 1.1205e+10
#  3.1000e+09 3.0000e+09 2.0000e+09 1.6434e+09 2.1580e+09 5.5000e+08
#  4.5000e+07 2.0750e+07 1.0600e+07 1.5000e+10 1.2450e+10 2.5500e+09
#  9.1300e+08 7.4700e+08 7.5000e+08 7.1700e+08 5.8100e+08 3.4860e+08
#  2.7000e+08 2.2600e+08 5.4000e+07 3.7500e+07 3.2000e+07 2.4900e+07
#  1.6000e+07 1.9400e+08 1.8675e+08 1.3446e+08 9.1300e+07 8.7980e+08
#  7.1380e+08 2.6560e+08 1.9920e+08 5.3950e+09 2.2825e+09 5.2290e+08
#  9.3790e+09 2.9000e+09 6.9305e+08 2.4800e+08 1.1000e+08 3.3200e+07
#  2.1000e+07 2.0900e+08 3.5690e+08 3.7500e+09 1.6600e+10 4.8500e+08
#  3.2000e+08 2.9880e+08 1.2450e+08 6.6400e+07 6.0000e+07 2.2600e+09
#  2.8220e+10 8.4000e+08 4.0000e+08 3.9000e+08 3.3500e+08 2.0500e+08
#  1.2035e+08 1.5000e+08 1.1500e+08 1.4500e+09 2.5000e+09 4.1900e+07
#  3.9425e+08 3.3000e+08 1.3280e+08 2.1100e+09 2.0800e+09 1.6900e+09
#  1.6700e+09 8.0000e+08 6.2250e+07 4.9800e+07 1.4570e+10 6.0000e+09
#  4.0000e+09 2.4470e+09 1.7015e+09 8.7500e+08 7.0000e+08 3.9000e+07
#  2.9050e+07 4.1000e+08 4.5000e+08 8.1340e+08 7.8850e+08 6.0000e+08
#  2.6700e+08 2.2410e+09 5.4000e+01 9.5450e+08 6.2250e+08 2.1580e+08
#  3.8346e+07 3.7350e+07 1.8600e+09 3.0000e+07 6.1700e+09 1.9090e+08
#  5.8930e+08 5.0630e+08 1.8260e+08 4.5000e+09 1.3000e+08 2.4153e+08
#  1.9339e+07 5.2207e+08 1.9339e+08 3.8678e+08 1.7430e+08 2.0999e+08
#  1.0707e+07 4.9800e+10 4.8555e+08 6.2250e+09 9.4620e+09 4.1998e+08
#  1.5355e+08 4.8472e+08 2.5730e+08 5.3800e+09 1.1300e+09 4.4820e+08
#  1.0292e+10 4.7500e+09 1.0000e+07 1.5770e+09 2.8000e+09 2.4070e+09
#  6.3800e+09 1.7430e+09 1.9090e+09 1.0790e+08 3.4000e+09 2.2000e+08
#  5.1000e+07 4.5650e+07 8.4000e+07 1.5521e+08 2.3000e+08 2.9880e+07
#  4.3000e+08 8.5000e+07 1.8094e+10 5.2000e+07 5.7000e+07 3.1125e+08
#  1.4700e+07 2.7390e+08 1.0126e+09 4.3990e+08 1.0375e+08 3.7000e+08
#  1.1205e+09 5.0000e+09 2.1000e+08 1.9000e+07 1.3600e+09 3.6000e+08
#  5.5610e+08 1.7000e+08 7.0550e+08 1.2500e+08 1.0873e+10 3.2490e+10
#  2.8000e+07 1.7500e+09 9.1300e+09 2.1400e+09 1.5000e+09 5.4780e+08
#  8.3000e+06 7.6000e+08 2.4500e+09 1.1100e+09 4.3000e+07 7.0000e+07
#  1.8000e+08 2.0833e+10 1.5700e+08 6.4740e+08 2.2410e+08 1.1620e+10
#  2.1580e+07 7.0000e+09 3.7350e+08 2.8600e+08 6.4740e+09 4.4820e+09
#  3.7350e+09 1.3300e+09 7.9680e+08 3.5275e+08 2.3240e+08 2.5520e+08
#  1.0375e+07 6.7230e+09 4.3500e+08 3.5000e+08 3.4600e+08 1.2000e+08
#  6.7500e+07 5.6000e+07 4.5650e+10 6.3500e+07 1.0043e+10 4.9500e+09
#  6.5000e+08 5.6000e+08 4.5650e+08 1.4276e+08 6.1000e+07 5.6000e+06
#  7.4700e+09 1.6100e+09 9.0000e+08 5.2705e+07 3.5690e+07 2.2825e+10
#  5.5000e+09 7.1000e+08 6.8890e+08 2.8220e+08 1.9000e+08]
# --------------------

# %%
df_combined['Lead_Investors_Clean'] = df_combined['Lead Investors'].fillna('').str.replace(r'&| and ', ',', regex=True)
df_combined['Investor_List'] = df_combined['Lead_Investors_Clean'].str.split(',').apply(lambda x: [i.strip() for i in x if i.strip()])
df_combined['num_investors'] = df_combined['Investor_List'].apply(len)

# %%
df_investors = df_combined.explode('Investor_List')
df_investors['Investor_List'] = df_investors['Investor_List'].str.lower().str.strip()

# %%
df_investors.head(2)
# Out:
#                          Company                    Sector   Headquarters  \
# 0  Zaggle Prepaid Ocean Services        Enterprise Fintech      Hyderabad
# 1                   EPACK Prefab  Pre-engineered Buildings  Greater Noida
#
#          Amount   Funding Round Type  \
# 0  Rs 595 crore        Funding Round
# 1   $20 million  First Funding Round
#
#                                       Lead Investors     Month  Year  \
# 0  Qualified Institutional Placement (Bank of Ind...  December  2024
# 1                               GEF Capital Partners  December  2024
#
#      Amount_INR                               Lead_Investors_Clean  \
# 0  5.950000e+09  Qualified Institutional Placement (Bank of Ind...
# 1  1.660000e+09                               GEF Capital Partners
#
#                                        Investor_List  num_investors
# 0  qualified institutional placement (bank of ind...              1
# 1                               gef capital partners              1

# %%
most_active = df_investors['Investor_List'].value_counts().reset_index()
most_active.columns = ['Investor', 'Startup_Count']

# %%
import altair as alt
# Create a bar chart to show the 'Startup_Count' for each 'Investor'.
# Sort the bars in descending order of 'Startup_Count'.
chart = alt.Chart(most_active).mark_bar().encode(
    x=alt.X('Investor', sort='-y'), # Set 'Investor' on the x-axis and sort by 'Startup_Count'
    y='Startup_Count', # Set 'Startup_Count' on the y-axis
    tooltip=['Investor', 'Startup_Count'] # Add tooltips for interactivity
).properties(
    title='Startup Count by Investor' # Add a title to the chart
)
chart
# Out:
# alt.Chart(...)

# %%
avg_ticket = df_investors.groupby('Investor_List')['Amount_INR'].mean().reset_index()
avg_ticket.columns = ['Investor', 'Avg_Amount_INR']
avg_ticket['Avg_Amount_INR'] = avg_ticket['Avg_Amount_INR'].round(2)
avg_ticket
# Out:
#                       Investor  Avg_Amount_INR
# 0                            -    7.422869e+09
# 1                   100unicorn    1.000000e+08
# 2                  100unicorns    6.225000e+07
# 3                      100x.vc    4.150000e+07
# 4                 10x founders    3.700000e+08
# ...                        ...             ...
# 1212              zeropearl vc    5.000000e+07
# 1213        zeropearl ventures    8.300000e+07
# 1214            zluri founders    1.162000e+08
# 1215          zoho corporation    1.300000e+09
# 1216  zomato’s deepinder goyal    3.320000e+08
#
# [1217 rows x 2 columns]

# %%
sector_pref = df_investors.groupby(['Investor_List', 'Sector']).size().reset_index(name='Count')
top_sectors = (
    sector_pref.sort_values(['Investor_List', 'Count'], ascending=[True, False])
)
top_sectors
# Out:
#                  Investor_List                             Sector  Count
# 0                            -                     Agri-financing      1
# 1                            -                Alternative Lending      1
# 2                            -              Compostable Packaging      1
# 3                            -               E-commerce Marketing      1
# 4                            -                 Financial Services      1
# ...                        ...                                ...    ...
# 1851              zeropearl vc                          Oral Care      1
# 1852        zeropearl ventures  Retail Luxury Goods and Jewellery      1
# 1853            zluri founders                   SaaS AI Platform      1
# 1854          zoho corporation                   EV Manufacturing      1
# 1855  zomato’s deepinder goyal                             Edtech      1
#
# [1856 rows x 3 columns]
